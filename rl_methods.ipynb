# %%
import riskfolio as rf

import matplotlib.pyplot as plt
import numpy as np
import pickle
import random

import pandas as pd

import gym
from gym import spaces

from stable_baselines3 import PPO, A2C, TD3, SAC, DDPG, DQN
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, VecFrameStack, SubprocVecEnv
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.evaluation import evaluate_policy

import torch

# %%
def softmax_normalization(actions):
    numerator = np.exp(actions)
    denominator = np.sum(np.exp(actions))
    softmax_output = numerator/denominator
    return softmax_output

# %% [markdown]
# ## Definition of gym Environment

# %%
# with open('data/sp500_it_components_7y.pickle', 'rb') as f:
#     test_data = pickle.load(f)
# test_data[0]['corrs']

# %%
class PortfolioAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, data_file,
                 objective = 'max_return',
                 risk_measure = 'MV',
                 observations_range = (0, 1259)):
        """
        Инициализация среды
        """
        super(PortfolioAllocationEnv, self).__init__()

        with open(data_file, 'rb') as f:
            self.data = pickle.load(f)
#             for d in self.data:
#                 d['corrs'] = d['corrs'].iloc[3:, :]

        self.stock_dim = self.data[0]['corrs'].shape[1]

        close_price_changes = {stock['ticker']: stock['data']['Close_change'] for stock in self.data}
        self.close_prices_pct = pd.DataFrame(close_price_changes)

        self.tickers = [stock['ticker'] for stock in self.data]
        self.n_assets = len(self.data)

        self.objective = objective
        self.risk_measure = risk_measure

        self.rewards_memory = None
        self.actions_memory = None

        self.portfolio_value = 0
        self.observations_range = observations_range
        self.current_step = observations_range[0]

        self.weights = np.ones(self.n_assets) / self.n_assets

        self.reward_range = (-10, 10)
        self.action_space = gym.spaces.Box(low=-1, high=1, shape=(self.n_assets,))
        self.observation_space = gym.spaces.Box(low=-np.inf, high=np.inf, shape=(self.n_assets, self.stock_dim + 1))

    def step(self, action):
        """
        Выполнение одного шага
        """
        # assert self.action_space.contains(action), "Invalid action"

        # Получаем текущее состояние
        state = self._get_state()

        # Вычисляем награду
        reward = self._get_reward(action)

        # Обновляем текущий шаг
        self.current_step += 1

        # Проверяем, достигнут ли конец эпизода
        done = self.current_step >= self.observations_range[1]

        if done:
            print(self.render())

        # Возвращаем состояние, награду и флаг окончания эпизода
        return state, reward, done, {}

    def reset(self):
        """
        Сброс среды в начальное состояние
        """
        self.portfolio_value = 0
        self.rewards_memory = []
        self.current_step = self.observations_range[0]
        self.actions_memory = []
        self.weights = np.ones(self.n_assets) / self.n_assets
        return self._get_state()

    def render(self, mode='human'):
        """
        Вывод информации о среде
        """
        return {
            'min_reward': min(self.rewards_memory),
            'max_reward': max(self.rewards_memory),
            'mean_reward': np.array(self.rewards_memory).mean(),
            'portfolio_value': self.portfolio_value,
            'weights_q0.25': np.quantile(self.weights, 0.25),
            'weights_q0.5': np.quantile(self.weights, 0.5),
            'weights_q0.75': np.quantile(self.weights, 0.75),
            'weights_max': np.max(self.weights),
            'weights_std': self.weights.std()
        }

    def _get_state(self):
        """
        Получение текущего состояния
        """
        values = [stock['corrs'].iloc[self.current_step].values for stock in self.data]
        observation = np.vstack(values)
        observation = np.concatenate([observation, self.weights[:, None]], axis=1).astype(np.float32)
        observation = np.nan_to_num(observation)
        return observation

    def _get_reward(self, action):
        """
        Вычисление награды
        """

        self.weights += action
        self.weights = softmax_normalization(self.weights)

        self.actions_memory.append(action)

        prices_change_hist = self.close_prices_pct.iloc[self.observations_range[0]:self.current_step + 1]
        current_prices = self.close_prices_pct.iloc[self.current_step].values

        portfolio_value_change = current_prices @ self.weights
        self.portfolio_value += portfolio_value_change

        reward = 0

        if self.objective == 'sharpe':
            mu = rf.mean_vector(prices_change_hist, method='hist')
            cov = rf.covar_matrix(prices_change_hist, method='shrunk')
            reward = rf.Sharpe(self.weights, mu, cov, prices_change_hist, rm=self.risk_measure)
        elif self.objective == 'price_change':
            # reward = portfolio_value_change
            reward = portfolio_value_change
        elif self.objective == 'min_risk':
            mu = rf.mean_vector(prices_change_hist, method='hist')
            cov = rf.covar_matrix(prices_change_hist, method='shrunk')
            reward = -rf.Sharpe_Risk(self.weights, cov, mu, rm=self.risk_measure)

        if np.isinf(reward):
            reward = 0

        self.rewards_memory.append(reward)
        # print('act', self.current_step, np.isnan(action).sum(), np.array(self.rewards_memory).mean())

        return reward

# %%
# class PortfolioAllocationEnv(gym.Env):
#     metadata = {'render.modes': ['human']}

#     def __init__(self, data_file,
#                  sector = None,
#                  objective = 'max_return',
#                  risk_measure = 'MV',
#                  drop_close = True,
#                  observations_range = (0, 1259)):
#         """
#         Инициализация среды
#         """
#         super(PortfolioAllocationEnv, self).__init__()

#         with open(data_file, 'rb') as f:
#             self.data = pickle.load(f)
#             if sector is not None:
#                 self.data = list(filter(lambda stock: stock['sector'] == sector, self.data))
#             if drop_close:
#                 for stock in self.data:
#                     stock['data'] = stock['data'].drop(['Close'], axis=1)

#         self.stock_dim = self.data[0]['data'].shape[1]

#         close_price_changes = {stock['ticker']: stock['data']['Close_Change'] for stock in self.data}
#         self.close_prices_pct = pd.DataFrame(close_price_changes)

#         self.tickers = [stock['ticker'] for stock in self.data]
#         self.n_assets = len(self.data)

#         self.objective = objective
#         self.risk_measure = risk_measure

#         self.rewards_memory = None
#         self.actions_memory = None

#         self.portfolio_value = 0
#         self.observations_range = observations_range
#         self.current_step = observations_range[0]

#         self.weights = np.ones(self.n_assets) / self.n_assets

#         self.reward_range = (-10, 10)
#         self.action_space = gym.spaces.Box(low=-1, high=1, shape=(self.n_assets,))
#         self.observation_space = gym.spaces.Box(low=-np.inf, high=np.inf, shape=(self.n_assets, self.stock_dim + 1))

#     def step(self, action):
#         """
#         Выполнение одного шага
#         """
#         # assert self.action_space.contains(action), "Invalid action"

#         # Получаем текущее состояние
#         state = self._get_state()

#         # Вычисляем награду
#         reward = self._get_reward(action)

#         # Обновляем текущий шаг
#         self.current_step += 1

#         # Проверяем, достигнут ли конец эпизода
#         done = self.current_step >= self.observations_range[1]

#         if done:
#             print(self.render())

#         # Возвращаем состояние, награду и флаг окончания эпизода
#         return state, reward, done, {}

#     def reset(self):
#         """
#         Сброс среды в начальное состояние
#         """
#         self.portfolio_value = 0
#         self.rewards_memory = []
#         self.current_step = self.observations_range[0]
#         self.actions_memory = []
#         self.weights = np.ones(self.n_assets) / self.n_assets
#         return self._get_state()

#     def render(self, mode='human'):
#         """
#         Вывод информации о среде
#         """
#         return {
#             'min_reward': min(self.rewards_memory),
#             'max_reward': max(self.rewards_memory),
#             'mean_reward': np.array(self.rewards_memory).mean(),
#             'portfolio_value': self.portfolio_value,
#             'weights_q0.25': np.quantile(self.weights, 0.25),
#             'weights_q0.5': np.quantile(self.weights, 0.5),
#             'weights_q0.75': np.quantile(self.weights, 0.75),
#             'weights_max': np.max(self.weights),
#             'weights_std': self.weights.std()
#         }

#     def _get_state(self):
#         """
#         Получение текущего состояния
#         """
#         values = [stock['data'].iloc[self.current_step].values for stock in self.data]
#         observation = np.vstack(values)
#         observation = np.concatenate([observation, self.weights[:, None]], axis=1).astype(np.float32)
#         observation = np.nan_to_num(observation)
#         return observation

#     def _get_reward(self, action):
#         """
#         Вычисление награды
#         """

#         self.weights += action
#         self.weights = softmax_normalization(self.weights)

#         self.actions_memory.append(action)

#         prices_change_hist = self.close_prices_pct.iloc[self.observations_range[0]:self.current_step + 1]
#         current_prices = self.close_prices_pct.iloc[self.current_step].values

#         portfolio_value_change = current_prices @ self.weights
#         self.portfolio_value += portfolio_value_change

#         reward = 0

#         if self.objective == 'sharpe':
#             mu = rf.mean_vector(prices_change_hist, method='hist')
#             cov = rf.covar_matrix(prices_change_hist, method='shrunk')
#             reward = rf.Sharpe(self.weights, mu, cov, prices_change_hist, rm=self.risk_measure)
#         elif self.objective == 'price_change':
#             # reward = portfolio_value_change
#             reward = portfolio_value_change
#         elif self.objective == 'min_risk':
#             mu = rf.mean_vector(prices_change_hist, method='hist')
#             cov = rf.covar_matrix(prices_change_hist, method='shrunk')
#             reward = -rf.Sharpe_Risk(self.weights, cov, mu, rm=self.risk_measure)

#         if np.isinf(reward):
#             reward = 0

#         self.rewards_memory.append(reward)
#         # print('act', self.current_step, np.isnan(action).sum(), np.array(self.rewards_memory).mean())

#         return reward

# %%
train_env = PortfolioAllocationEnv(data_file='data/sp500_re_components_7y.pickle',
#                                    sector='Information Technology',
                                   objective='price_change',
#                                    drop_close=False,
                                   observations_range=(0, 1260))  # 252 x 5 = 1260, 252 x 3 = 756
check_env(train_env, skip_render_check=False)
# Out:
# /home/hivaze/Documents/CODE-W/PyCharm Projects/portfolio_optimization/venv/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:213: UserWarning: Your observation  has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(

# %%
len(train_env.data[0]['corrs'])
# Out:
# 1760

# %% [markdown]
# ### Vectorization of Env

# %%
from stable_baselines3.common.vec_env import VecCheckNan

train_env = DummyVecEnv([lambda: train_env])
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=False)
train_env = VecCheckNan(train_env, raise_exception=True)
# train_env = VecFrameStack(train_env, 15, channels_order='first')

# %%
train_env.observation_space.shape, train_env.action_space.shape
# Out:
# ((28, 41), (28,))

# %% [markdown]
# ## stablebaselines Models

# %%
from stable_baselines3.ppo import MlpPolicy
from sb3_contrib.ppo_recurrent import MlpLstmPolicy
from sb3_contrib import RecurrentPPO

# %%
DDPG?

# %%
model = SAC('MlpPolicy', train_env, learning_rate=1e-3, buffer_size=20_000,
            verbose=1, tensorboard_log='logs/',
            device='cuda', batch_size=128,
#             policy_kwargs={'net_arch': [800, 400]}
            )
model.policy
# Out:
# Using cuda device
# SACPolicy(
#   (actor): Actor(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (latent_pi): Sequential(
#       (0): Linear(in_features=1148, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#     )
#     (mu): Linear(in_features=256, out_features=28, bias=True)
#     (log_std): Linear(in_features=256, out_features=28, bias=True)
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=1176, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=1176, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=1176, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=1176, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
mean_reward, std_reward = evaluate_policy(model, train_env, n_eval_episodes=1, deterministic=False, warn=False, return_episode_rewards=True)
print(mean_reward, std_reward)
# Out:
# {'min_reward': -0.17888513111263077, 'max_reward': 0.1016405990048536, 'mean_reward': 0.00027419362430891305, 'portfolio_value': 0.3454839666292308, 'weights_q0.25': 0.019981438691910217, 'weights_q0.5': 0.025651049657377967, 'weights_q0.75': 0.0489902893783318, 'weights_max': 0.09459255277172963, 'weights_std': 0.022267354644032733}
# [0.3454839686530704] [1260]

# %% [markdown]
# ### Learn loop

# %%
# eval_callback = EvalCallback(eval_env=test_env, best_model_save_path='models/best.stbl',
#                              n_eval_episodes=3, eval_freq=500, render=False, warn=False)
# eval_callback

# %%
class MeanRewardCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(MeanRewardCallback, self).__init__(verbose)
        self.render = {}

    def _on_step(self) -> bool:

        if self.training_env.get_attr('rewards_memory')[0]:  # else - end of episode
            # reward = self.training_env.get_attr('rewards_memory')[0][-1]
            self.render = self.training_env.render()
        else:
            self.logger.record("train/mean_reward", self.render['mean_reward'])
            self.logger.record("train/min_reward", self.render['min_reward'])
            self.logger.record("train/max_reward", self.render['max_reward'])
            self.logger.record("train/portfolio_value", self.render['portfolio_value'])

        return True

# %%
model_name = 'SAC-mr-re-256-256-corrs-dw'
model.learn(total_timesteps=150_000, progress_bar=False, log_interval=1,
            reset_num_timesteps=False, tb_log_name=model_name,
            callback=MeanRewardCallback())
# Out:
# Logging to logs/SAC-mr-re-256-256-corrs-dw_0
# {'min_reward': -0.1788921409979694, 'max_reward': 0.08892297520103949, 'mean_reward': 0.0002711987671513675, 'portfolio_value': 0.3417104466107232, 'weights_q0.25': 0.020148079638662754, 'weights_q0.5': 0.031008298210897442, 'weights_q0.75': 0.05254317331350907, 'weights_max': 0.08901289524707764, 'weights_std': 0.01875007540657821}
# ---------------------------------
# | time/              |          |
# |    episodes        | 1        |
# |    fps             | 148      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 1260     |
# | train/             |          |
# |    actor_loss      | -47.3    |
# |    critic_loss     | 0.46     |
# |    ent_coef        | 0.315    |
# |    ent_coef_loss   | -53.6    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0889   |
# |    mean_reward     | 0.000266 |
# |    min_reward      | -0.179   |
# |    n_updates       | 1159     |
# |    portfolio_value | 0.335    |
# ---------------------------------
# {'min_reward': -0.17776950402654695, 'max_reward': 0.09594755746237613, 'mean_reward': 0.00027559970710009887, 'portfolio_value': 0.34725563094612444, 'weights_q0.25': 0.015876506494467313, 'weights_q0.5': 0.02382157808848163, 'weights_q0.75': 0.05469292037239775, 'weights_max': 0.07497357363768019, 'weights_std': 0.021401540583173163}
# ---------------------------------
# | time/              |          |
# |    episodes        | 2        |
# |    fps             | 140      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 2520     |
# | train/             |          |
# |    actor_loss      | -53.4    |
# |    critic_loss     | 0.634    |
# |    ent_coef        | 0.0908   |
# |    ent_coef_loss   | -107     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0959   |
# |    mean_reward     | 0.000272 |
# |    min_reward      | -0.178   |
# |    n_updates       | 2419     |
# |    portfolio_value | 0.342    |
# ---------------------------------
# {'min_reward': -0.16567815796731344, 'max_reward': 0.09386553503207194, 'mean_reward': 0.0002772861494403835, 'portfolio_value': 0.34938054829488324, 'weights_q0.25': 0.01866882873871612, 'weights_q0.5': 0.031910091326463684, 'weights_q0.75': 0.050676020022143095, 'weights_max': 0.0699057539823709, 'weights_std': 0.019453614499902367}
# ---------------------------------
# | time/              |          |
# |    episodes        | 3        |
# |    fps             | 138      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 3780     |
# | train/             |          |
# |    actor_loss      | -53.1    |
# |    critic_loss     | 1.48     |
# |    ent_coef        | 0.0269   |
# |    ent_coef_loss   | -148     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0939   |
# |    mean_reward     | 0.000272 |
# |    min_reward      | -0.166   |
# |    n_updates       | 3679     |
# |    portfolio_value | 0.342    |
# ---------------------------------
# {'min_reward': -0.17661005439688676, 'max_reward': 0.0968577871876242, 'mean_reward': 0.00023518424217796447, 'portfolio_value': 0.29633214514423545, 'weights_q0.25': 0.011773713211947555, 'weights_q0.5': 0.03832457035834002, 'weights_q0.75': 0.05878331377039516, 'weights_max': 0.06657975259321194, 'weights_std': 0.02280895475053205}
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 136      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 5040     |
# | train/             |          |
# |    actor_loss      | -49.8    |
# |    critic_loss     | 0.169    |
# |    ent_coef        | 0.0086   |
# |    ent_coef_loss   | -169     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0969   |
# |    mean_reward     | 0.000231 |
# |    min_reward      | -0.177   |
# |    n_updates       | 4939     |
# |    portfolio_value | 0.291    |
# ---------------------------------
# {'min_reward': -0.1642885630744203, 'max_reward': 0.08957280299616173, 'mean_reward': 0.00027495162272798436, 'portfolio_value': 0.34643904463726, 'weights_q0.25': 0.010541012994916672, 'weights_q0.5': 0.04046331202581439, 'weights_q0.75': 0.054021169345830615, 'weights_max': 0.06554679934037765, 'weights_std': 0.021393175852069752}
# ---------------------------------
# | time/              |          |
# |    episodes        | 5        |
# |    fps             | 135      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 6300     |
# | train/             |          |
# |    actor_loss      | -47.7    |
# |    critic_loss     | 0.116    |
# |    ent_coef        | 0.00315  |
# |    ent_coef_loss   | -117     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0896   |
# |    mean_reward     | 0.000266 |
# |    min_reward      | -0.164   |
# |    n_updates       | 6199     |
# |    portfolio_value | 0.335    |
# ---------------------------------
# {'min_reward': -0.17685526258052509, 'max_reward': 0.10071327107730713, 'mean_reward': 0.00028355453744874457, 'portfolio_value': 0.35727871718541837, 'weights_q0.25': 0.01540131271081177, 'weights_q0.5': 0.033950344236984786, 'weights_q0.75': 0.05217270379689902, 'weights_max': 0.06905003694402949, 'weights_std': 0.019908963758010496}
# ---------------------------------
# | time/              |          |
# |    episodes        | 6        |
# |    fps             | 134      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 7560     |
# | train/             |          |
# |    actor_loss      | -44.5    |
# |    critic_loss     | 0.0847   |
# |    ent_coef        | 0.00149  |
# |    ent_coef_loss   | -57.1    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.101    |
# |    mean_reward     | 0.000276 |
# |    min_reward      | -0.177   |
# |    n_updates       | 7459     |
# |    portfolio_value | 0.347    |
# ---------------------------------
# {'min_reward': -0.16607311880009984, 'max_reward': 0.09411526224584453, 'mean_reward': 0.00021708746595614872, 'portfolio_value': 0.2735302071047473, 'weights_q0.25': 0.014331516973116586, 'weights_q0.5': 0.022847301257500497, 'weights_q0.75': 0.06210009507285814, 'weights_max': 0.07196777129124604, 'weights_std': 0.023700947321897994}
# ---------------------------------
# | time/              |          |
# |    episodes        | 7        |
# |    fps             | 134      |
# |    time_elapsed    | 65       |
# |    total_timesteps | 8820     |
# | train/             |          |
# |    actor_loss      | -43.2    |
# |    critic_loss     | 0.165    |
# |    ent_coef        | 0.000955 |
# |    ent_coef_loss   | -33.6    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0941   |
# |    mean_reward     | 0.000211 |
# |    min_reward      | -0.166   |
# |    n_updates       | 8719     |
# |    portfolio_value | 0.265    |
# ---------------------------------
# {'min_reward': -0.1780167657898209, 'max_reward': 0.128975039317278, 'mean_reward': 0.00031517427640407805, 'portfolio_value': 0.39711958826913807, 'weights_q0.25': 0.01430584755110123, 'weights_q0.5': 0.026706126073871597, 'weights_q0.75': 0.053805655977679716, 'weights_max': 0.07094407431370423, 'weights_std': 0.021958210662545715}
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 133      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 10080    |
# | train/             |          |
# |    actor_loss      | -40.4    |
# |    critic_loss     | 0.0302   |
# |    ent_coef        | 0.000775 |
# |    ent_coef_loss   | -36.5    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.129    |
# |    mean_reward     | 0.000305 |
# |    min_reward      | -0.178   |
# |    n_updates       | 9979     |
# |    portfolio_value | 0.384    |
# ---------------------------------
# {'min_reward': -0.17522516734836246, 'max_reward': 0.09221875400170165, 'mean_reward': 0.00024887724098327673, 'portfolio_value': 0.3135853236389283, 'weights_q0.25': 0.012559004471986226, 'weights_q0.5': 0.026235073589073055, 'weights_q0.75': 0.058989439713415956, 'weights_max': 0.06678640111443437, 'weights_std': 0.022046936890473108}
# ---------------------------------
# | time/              |          |
# |    episodes        | 9        |
# |    fps             | 133      |
# |    time_elapsed    | 84       |
# |    total_timesteps | 11340    |
# | train/             |          |
# |    actor_loss      | -35.5    |
# |    critic_loss     | 0.244    |
# |    ent_coef        | 0.0006   |
# |    ent_coef_loss   | -7.45    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0922   |
# |    mean_reward     | 0.000241 |
# |    min_reward      | -0.175   |
# |    n_updates       | 11239    |
# |    portfolio_value | 0.303    |
# ---------------------------------
# {'min_reward': -0.17885128215343749, 'max_reward': 0.1259980923644234, 'mean_reward': 0.00029960163746818743, 'portfolio_value': 0.3774980632099162, 'weights_q0.25': 0.01502203438845991, 'weights_q0.5': 0.03062525712245362, 'weights_q0.75': 0.05189125820344894, 'weights_max': 0.07333904550270333, 'weights_std': 0.022123288943855696}
# ---------------------------------
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 133      |
# |    time_elapsed    | 94       |
# |    total_timesteps | 12600    |
# | train/             |          |
# |    actor_loss      | -33.3    |
# |    critic_loss     | 0.051    |
# |    ent_coef        | 0.000514 |
# |    ent_coef_loss   | 5.26     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.126    |
# |    mean_reward     | 0.00029  |
# |    min_reward      | -0.179   |
# |    n_updates       | 12499    |
# |    portfolio_value | 0.365    |
# ---------------------------------
# {'min_reward': -0.16383123820120393, 'max_reward': 0.09945964230866391, 'mean_reward': 0.00028575798836815813, 'portfolio_value': 0.3600550653438795, 'weights_q0.25': 0.01626869566724784, 'weights_q0.5': 0.03429609347619793, 'weights_q0.75': 0.0538708346766605, 'weights_max': 0.06460970614696802, 'weights_std': 0.019065402353665994}
# ---------------------------------
# | time/              |          |
# |    episodes        | 11       |
# |    fps             | 133      |
# |    time_elapsed    | 103      |
# |    total_timesteps | 13860    |
# | train/             |          |
# |    actor_loss      | -33      |
# |    critic_loss     | 0.0298   |
# |    ent_coef        | 0.000424 |
# |    ent_coef_loss   | -18.3    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0995   |
# |    mean_reward     | 0.000281 |
# |    min_reward      | -0.164   |
# |    n_updates       | 13759    |
# |    portfolio_value | 0.353    |
# ---------------------------------
# {'min_reward': -0.1703766097306515, 'max_reward': 0.0968123386933683, 'mean_reward': 0.00028573847410702394, 'portfolio_value': 0.36003047737485, 'weights_q0.25': 0.01195283838302446, 'weights_q0.5': 0.03690837396625492, 'weights_q0.75': 0.05819514629228399, 'weights_max': 0.07153077754625262, 'weights_std': 0.02159133559653328}
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 133      |
# |    time_elapsed    | 113      |
# |    total_timesteps | 15120    |
# | train/             |          |
# |    actor_loss      | -30.2    |
# |    critic_loss     | 0.00637  |
# |    ent_coef        | 0.000295 |
# |    ent_coef_loss   | -1.96    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0968   |
# |    mean_reward     | 0.000281 |
# |    min_reward      | -0.17    |
# |    n_updates       | 15019    |
# |    portfolio_value | 0.354    |
# ---------------------------------
# {'min_reward': -0.167507510208878, 'max_reward': 0.08428488825870914, 'mean_reward': 0.0002540110739531483, 'portfolio_value': 0.3200539531809672, 'weights_q0.25': 0.022292500624570392, 'weights_q0.5': 0.030906488429811238, 'weights_q0.75': 0.047742220604502894, 'weights_max': 0.10804451095600298, 'weights_std': 0.019788897465081626}
# ---------------------------------
# | time/              |          |
# |    episodes        | 13       |
# |    fps             | 133      |
# |    time_elapsed    | 123      |
# |    total_timesteps | 16380    |
# | train/             |          |
# |    actor_loss      | -26.9    |
# |    critic_loss     | 0.00842  |
# |    ent_coef        | 0.00037  |
# |    ent_coef_loss   | -82.6    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0843   |
# |    mean_reward     | 0.000251 |
# |    min_reward      | -0.168   |
# |    n_updates       | 16279    |
# |    portfolio_value | 0.316    |
# ---------------------------------
# {'min_reward': -0.1775120025211414, 'max_reward': 0.11352773781429978, 'mean_reward': 0.00027314428179070575, 'portfolio_value': 0.34416179505628886, 'weights_q0.25': 0.02075944457532508, 'weights_q0.5': 0.031113523517075137, 'weights_q0.75': 0.05098078462077388, 'weights_max': 0.07064996946967686, 'weights_std': 0.01780995179140179}
# ---------------------------------
# | time/              |          |
# |    episodes        | 14       |
# |    fps             | 132      |
# |    time_elapsed    | 132      |
# |    total_timesteps | 17640    |
# | train/             |          |
# |    actor_loss      | -26      |
# |    critic_loss     | 0.122    |
# |    ent_coef        | 0.000302 |
# |    ent_coef_loss   | 1.68     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.114    |
# |    mean_reward     | 0.00027  |
# |    min_reward      | -0.178   |
# |    n_updates       | 17539    |
# |    portfolio_value | 0.34     |
# ---------------------------------
# {'min_reward': -0.18077467555274185, 'max_reward': 0.11737016693181906, 'mean_reward': 0.00016034533340228164, 'portfolio_value': 0.20203512008687446, 'weights_q0.25': 0.016743625514873024, 'weights_q0.5': 0.030670175246381045, 'weights_q0.75': 0.05340858217599656, 'weights_max': 0.07169013628818219, 'weights_std': 0.019829494544616893}
# ---------------------------------
# | time/              |          |
# |    episodes        | 15       |
# |    fps             | 132      |
# |    time_elapsed    | 142      |
# |    total_timesteps | 18900    |
# | train/             |          |
# |    actor_loss      | -23.9    |
# |    critic_loss     | 0.0191   |
# |    ent_coef        | 0.000286 |
# |    ent_coef_loss   | -33.4    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.117    |
# |    mean_reward     | 0.000159 |
# |    min_reward      | -0.181   |
# |    n_updates       | 18799    |
# |    portfolio_value | 0.201    |
# ---------------------------------
# {'min_reward': -0.16907073575639142, 'max_reward': 0.10872177818117859, 'mean_reward': 0.00023477694572861943, 'portfolio_value': 0.2958189516180602, 'weights_q0.25': 0.022252817076532, 'weights_q0.5': 0.031019177344093936, 'weights_q0.75': 0.0477526255242322, 'weights_max': 0.07804443762598025, 'weights_std': 0.017738317229098282}
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 132      |
# |    time_elapsed    | 151      |
# |    total_timesteps | 20160    |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 0.0129   |
# |    ent_coef        | 0.000271 |
# |    ent_coef_loss   | -1.65    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.109    |
# |    mean_reward     | 0.000225 |
# |    min_reward      | -0.169   |
# |    n_updates       | 20059    |
# |    portfolio_value | 0.283    |
# ---------------------------------
# {'min_reward': -0.17997479595109458, 'max_reward': 0.10072190037236306, 'mean_reward': 0.00033971614493506254, 'portfolio_value': 0.4280423426181789, 'weights_q0.25': 0.02050605325051722, 'weights_q0.5': 0.02469789751837893, 'weights_q0.75': 0.05521122360688417, 'weights_max': 0.08111776030495897, 'weights_std': 0.02102403861527365}
# ---------------------------------
# | time/              |          |
# |    episodes        | 17       |
# |    fps             | 132      |
# |    time_elapsed    | 161      |
# |    total_timesteps | 21420    |
# | train/             |          |
# |    actor_loss      | -21.7    |
# |    critic_loss     | 0.00654  |
# |    ent_coef        | 0.000162 |
# |    ent_coef_loss   | 39.6     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.101    |
# |    mean_reward     | 0.000331 |
# |    min_reward      | -0.18    |
# |    n_updates       | 21319    |
# |    portfolio_value | 0.416    |
# ---------------------------------
# {'min_reward': -0.17159943302554048, 'max_reward': 0.12620310652029593, 'mean_reward': 0.00031945357125611834, 'portfolio_value': 0.4025114997827091, 'weights_q0.25': 0.021024053942492574, 'weights_q0.5': 0.03305607912499124, 'weights_q0.75': 0.04736889074923219, 'weights_max': 0.07252321435955687, 'weights_std': 0.017192345513482393}
# ---------------------------------
# | time/              |          |
# |    episodes        | 18       |
# |    fps             | 132      |
# |    time_elapsed    | 170      |
# |    total_timesteps | 22680    |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 0.0119   |
# |    ent_coef        | 0.00025  |
# |    ent_coef_loss   | -0.316   |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.126    |
# |    mean_reward     | 0.000311 |
# |    min_reward      | -0.172   |
# |    n_updates       | 22579    |
# |    portfolio_value | 0.392    |
# ---------------------------------
# {'min_reward': -0.17069456722223045, 'max_reward': 0.08590975509671253, 'mean_reward': 0.0003268243721808611, 'portfolio_value': 0.4117987089478838, 'weights_q0.25': 0.0252067170377713, 'weights_q0.5': 0.03415465150326273, 'weights_q0.75': 0.0410142446586077, 'weights_max': 0.06916042662412752, 'weights_std': 0.015457435630642398}
# ---------------------------------
# | time/              |          |
# |    episodes        | 19       |
# |    fps             | 132      |
# |    time_elapsed    | 180      |
# |    total_timesteps | 23940    |
# | train/             |          |
# |    actor_loss      | -17.3    |
# |    critic_loss     | 0.011    |
# |    ent_coef        | 0.000226 |
# |    ent_coef_loss   | -12.8    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0859   |
# |    mean_reward     | 0.000321 |
# |    min_reward      | -0.171   |
# |    n_updates       | 23839    |
# |    portfolio_value | 0.404    |
# ---------------------------------
# {'min_reward': -0.18017314337973067, 'max_reward': 0.10413761744526664, 'mean_reward': 0.00025756308124854244, 'portfolio_value': 0.3245294823731636, 'weights_q0.25': 0.02264912476856341, 'weights_q0.5': 0.030542603121023696, 'weights_q0.75': 0.04543163545267782, 'weights_max': 0.07587538477469072, 'weights_std': 0.016265278860420725}
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 132      |
# |    time_elapsed    | 189      |
# |    total_timesteps | 25200    |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 0.00198  |
# |    ent_coef        | 0.000151 |
# |    ent_coef_loss   | -61.9    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.104    |
# |    mean_reward     | 0.000252 |
# |    min_reward      | -0.18    |
# |    n_updates       | 25099    |
# |    portfolio_value | 0.317    |
# ---------------------------------
# {'min_reward': -0.17208151940712194, 'max_reward': 0.11147726058675778, 'mean_reward': 0.00033319903119317663, 'portfolio_value': 0.4198307793034029, 'weights_q0.25': 0.02368491180267775, 'weights_q0.5': 0.03418401450682587, 'weights_q0.75': 0.04992182597678794, 'weights_max': 0.06297536385646157, 'weights_std': 0.015156241309790527}
# ---------------------------------
# | time/              |          |
# |    episodes        | 21       |
# |    fps             | 132      |
# |    time_elapsed    | 199      |
# |    total_timesteps | 26460    |
# | train/             |          |
# |    actor_loss      | -15.8    |
# |    critic_loss     | 0.00164  |
# |    ent_coef        | 0.000136 |
# |    ent_coef_loss   | -27.2    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.111    |
# |    mean_reward     | 0.000326 |
# |    min_reward      | -0.172   |
# |    n_updates       | 26359    |
# |    portfolio_value | 0.411    |
# ---------------------------------
# {'min_reward': -0.17568006172851147, 'max_reward': 0.1297642469795704, 'mean_reward': 0.0002861133576873742, 'portfolio_value': 0.36050283068609107, 'weights_q0.25': 0.020491485228405548, 'weights_q0.5': 0.030096536239338514, 'weights_q0.75': 0.047163904036050086, 'weights_max': 0.07504056977511453, 'weights_std': 0.016982510456461417}
# ---------------------------------
# | time/              |          |
# |    episodes        | 22       |
# |    fps             | 132      |
# |    time_elapsed    | 208      |
# |    total_timesteps | 27720    |
# | train/             |          |
# |    actor_loss      | -13.8    |
# |    critic_loss     | 0.00147  |
# |    ent_coef        | 0.000113 |
# |    ent_coef_loss   | -40.9    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.13     |
# |    mean_reward     | 0.00028  |
# |    min_reward      | -0.176   |
# |    n_updates       | 27619    |
# |    portfolio_value | 0.352    |
# ---------------------------------
# {'min_reward': -0.180410045426663, 'max_reward': 0.09912433499762066, 'mean_reward': 0.0002493099792288982, 'portfolio_value': 0.3141305738284116, 'weights_q0.25': 0.021612835946821424, 'weights_q0.5': 0.03463043329672876, 'weights_q0.75': 0.04797463928221666, 'weights_max': 0.0648266761751099, 'weights_std': 0.015305041849751944}
# ---------------------------------
# | time/              |          |
# |    episodes        | 23       |
# |    fps             | 132      |
# |    time_elapsed    | 218      |
# |    total_timesteps | 28980    |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 0.00161  |
# |    ent_coef        | 0.000137 |
# |    ent_coef_loss   | -75.3    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0991   |
# |    mean_reward     | 0.000243 |
# |    min_reward      | -0.18    |
# |    n_updates       | 28879    |
# |    portfolio_value | 0.305    |
# ---------------------------------
# {'min_reward': -0.1752098252425187, 'max_reward': 0.13387384462674545, 'mean_reward': 0.00029119166008607813, 'portfolio_value': 0.36690149170845887, 'weights_q0.25': 0.024661645957613165, 'weights_q0.5': 0.03204790465555773, 'weights_q0.75': 0.046649005282086764, 'weights_max': 0.06633334526128115, 'weights_std': 0.01503064522048948}
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 132      |
# |    time_elapsed    | 227      |
# |    total_timesteps | 30240    |
# | train/             |          |
# |    actor_loss      | -12.8    |
# |    critic_loss     | 0.00447  |
# |    ent_coef        | 9.57e-05 |
# |    ent_coef_loss   | -15.9    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.134    |
# |    mean_reward     | 0.000286 |
# |    min_reward      | -0.175   |
# |    n_updates       | 30139    |
# |    portfolio_value | 0.36     |
# ---------------------------------
# {'min_reward': -0.17343264115504817, 'max_reward': 0.10816000964059043, 'mean_reward': 0.00034212823939993735, 'portfolio_value': 0.43108158164392085, 'weights_q0.25': 0.02448052471829714, 'weights_q0.5': 0.03172525177123617, 'weights_q0.75': 0.0432277831299036, 'weights_max': 0.06881715728080376, 'weights_std': 0.016106150566947707}
# ---------------------------------
# | time/              |          |
# |    episodes        | 25       |
# |    fps             | 132      |
# |    time_elapsed    | 237      |
# |    total_timesteps | 31500    |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 0.00187  |
# |    ent_coef        | 9.68e-05 |
# |    ent_coef_loss   | -19.9    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.108    |
# |    mean_reward     | 0.000338 |
# |    min_reward      | -0.173   |
# |    n_updates       | 31399    |
# |    portfolio_value | 0.426    |
# ---------------------------------
# {'min_reward': -0.17881555327044596, 'max_reward': 0.14533142944265892, 'mean_reward': 0.00023314717984991925, 'portfolio_value': 0.2937654466108985, 'weights_q0.25': 0.018827073971038617, 'weights_q0.5': 0.02927606154982903, 'weights_q0.75': 0.05160993355624802, 'weights_max': 0.07886598585853839, 'weights_std': 0.02087682469419661}
# ---------------------------------
# | time/              |          |
# |    episodes        | 26       |
# |    fps             | 132      |
# |    time_elapsed    | 246      |
# |    total_timesteps | 32760    |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 0.000859 |
# |    ent_coef        | 7.33e-05 |
# |    ent_coef_loss   | -16.8    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.145    |
# |    mean_reward     | 0.00023  |
# |    min_reward      | -0.179   |
# |    n_updates       | 32659    |
# |    portfolio_value | 0.29     |
# ---------------------------------
# {'min_reward': -0.18260840471316375, 'max_reward': 0.1566893581181506, 'mean_reward': 0.00026053322200664817, 'portfolio_value': 0.3282718597283767, 'weights_q0.25': 0.02112663762716304, 'weights_q0.5': 0.03124859947161717, 'weights_q0.75': 0.04444806127272026, 'weights_max': 0.07209054705985635, 'weights_std': 0.01819277097985851}
# ---------------------------------
# | time/              |          |
# |    episodes        | 27       |
# |    fps             | 132      |
# |    time_elapsed    | 256      |
# |    total_timesteps | 34020    |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 0.000719 |
# |    ent_coef        | 6.52e-05 |
# |    ent_coef_loss   | -63.5    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.157    |
# |    mean_reward     | 0.000256 |
# |    min_reward      | -0.183   |
# |    n_updates       | 33919    |
# |    portfolio_value | 0.322    |
# ---------------------------------
# {'min_reward': -0.17865659519297905, 'max_reward': 0.14562616676973522, 'mean_reward': 0.0003682611643490276, 'portfolio_value': 0.46400906707977524, 'weights_q0.25': 0.02045672453129592, 'weights_q0.5': 0.035595033270397064, 'weights_q0.75': 0.04859479027766392, 'weights_max': 0.06774716648036291, 'weights_std': 0.0174308447847073}
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 132      |
# |    time_elapsed    | 265      |
# |    total_timesteps | 35280    |
# | train/             |          |
# |    actor_loss      | -9.6     |
# |    critic_loss     | 0.000623 |
# |    ent_coef        | 7.59e-05 |
# |    ent_coef_loss   | -63.4    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.146    |
# |    mean_reward     | 0.000359 |
# |    min_reward      | -0.179   |
# |    n_updates       | 35179    |
# |    portfolio_value | 0.452    |
# ---------------------------------
# {'min_reward': -0.1797662494113489, 'max_reward': 0.1373023205009341, 'mean_reward': 0.00032652776554094727, 'portfolio_value': 0.41142498458159316, 'weights_q0.25': 0.022838573105382638, 'weights_q0.5': 0.030289550704986117, 'weights_q0.75': 0.05069767306423671, 'weights_max': 0.06729319026886857, 'weights_std': 0.015980155459624782}
# ---------------------------------
# | time/              |          |
# |    episodes        | 29       |
# |    fps             | 132      |
# |    time_elapsed    | 275      |
# |    total_timesteps | 36540    |
# | train/             |          |
# |    actor_loss      | -9.32    |
# |    critic_loss     | 0.00151  |
# |    ent_coef        | 5.12e-05 |
# |    ent_coef_loss   | -44.5    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.137    |
# |    mean_reward     | 0.000319 |
# |    min_reward      | -0.18    |
# |    n_updates       | 36439    |
# |    portfolio_value | 0.401    |
# ---------------------------------
# {'min_reward': -0.18253311499736227, 'max_reward': 0.17603082304181417, 'mean_reward': 0.0003536813997779294, 'portfolio_value': 0.4456385637201914, 'weights_q0.25': 0.02554732210978371, 'weights_q0.5': 0.03321582411322796, 'weights_q0.75': 0.04208429345190583, 'weights_max': 0.06970764275161868, 'weights_std': 0.016397566180146712}
# ---------------------------------
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 132      |
# |    time_elapsed    | 284      |
# |    total_timesteps | 37800    |
# | train/             |          |
# |    actor_loss      | -8.6     |
# |    critic_loss     | 0.00105  |
# |    ent_coef        | 5.08e-05 |
# |    ent_coef_loss   | 106      |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.176    |
# |    mean_reward     | 0.000348 |
# |    min_reward      | -0.183   |
# |    n_updates       | 37699    |
# |    portfolio_value | 0.438    |
# ---------------------------------
# {'min_reward': -0.1780246584034298, 'max_reward': 0.1410809006191295, 'mean_reward': 0.00042320135704972854, 'portfolio_value': 0.5332337098826577, 'weights_q0.25': 0.020189834508879585, 'weights_q0.5': 0.030336519714738136, 'weights_q0.75': 0.048356383223541924, 'weights_max': 0.07563065186642966, 'weights_std': 0.018574165060274032}
# ---------------------------------
# | time/              |          |
# |    episodes        | 31       |
# |    fps             | 132      |
# |    time_elapsed    | 294      |
# |    total_timesteps | 39060    |
# | train/             |          |
# |    actor_loss      | -7.41    |
# |    critic_loss     | 0.00213  |
# |    ent_coef        | 4.76e-05 |
# |    ent_coef_loss   | 17.7     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.141    |
# |    mean_reward     | 0.000418 |
# |    min_reward      | -0.178   |
# |    n_updates       | 38959    |
# |    portfolio_value | 0.527    |
# ---------------------------------
# {'min_reward': -0.17043005120506605, 'max_reward': 0.13571417203725267, 'mean_reward': 0.000452798297510152, 'portfolio_value': 0.5705258548627913, 'weights_q0.25': 0.020327708337270448, 'weights_q0.5': 0.03338812573625921, 'weights_q0.75': 0.05036219902465708, 'weights_max': 0.06681998419301446, 'weights_std': 0.015847170389743332}
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 132      |
# |    time_elapsed    | 303      |
# |    total_timesteps | 40320    |
# | train/             |          |
# |    actor_loss      | -7.23    |
# |    critic_loss     | 0.000525 |
# |    ent_coef        | 4.56e-05 |
# |    ent_coef_loss   | -14.6    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.136    |
# |    mean_reward     | 0.000446 |
# |    min_reward      | -0.17    |
# |    n_updates       | 40219    |
# |    portfolio_value | 0.561    |
# ---------------------------------
# {'min_reward': -0.1701870361836503, 'max_reward': 0.1599153666953267, 'mean_reward': 0.0004155272998195134, 'portfolio_value': 0.5235643977725866, 'weights_q0.25': 0.022528531039699616, 'weights_q0.5': 0.03194717460372682, 'weights_q0.75': 0.0496849539328672, 'weights_max': 0.0662773881421025, 'weights_std': 0.015570453902080084}
# ---------------------------------
# | time/              |          |
# |    episodes        | 33       |
# |    fps             | 132      |
# |    time_elapsed    | 313      |
# |    total_timesteps | 41580    |
# | train/             |          |
# |    actor_loss      | -6.87    |
# |    critic_loss     | 0.000376 |
# |    ent_coef        | 4.01e-05 |
# |    ent_coef_loss   | -38.3    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.16     |
# |    mean_reward     | 0.00041  |
# |    min_reward      | -0.17    |
# |    n_updates       | 41479    |
# |    portfolio_value | 0.516    |
# ---------------------------------
# {'min_reward': -0.18448701378805094, 'max_reward': 0.17248144559287304, 'mean_reward': 0.0004466997614095702, 'portfolio_value': 0.5628416993760579, 'weights_q0.25': 0.02311136697673262, 'weights_q0.5': 0.03663173470054805, 'weights_q0.75': 0.045536476925979424, 'weights_max': 0.06785512937965064, 'weights_std': 0.014917274255871133}
# ---------------------------------
# | time/              |          |
# |    episodes        | 34       |
# |    fps             | 132      |
# |    time_elapsed    | 322      |
# |    total_timesteps | 42840    |
# | train/             |          |
# |    actor_loss      | -5.94    |
# |    critic_loss     | 0.000171 |
# |    ent_coef        | 4.1e-05  |
# |    ent_coef_loss   | -112     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.172    |
# |    mean_reward     | 0.00044  |
# |    min_reward      | -0.184   |
# |    n_updates       | 42739    |
# |    portfolio_value | 0.554    |
# ---------------------------------
# {'min_reward': -0.184218627778361, 'max_reward': 0.09720943119562102, 'mean_reward': 0.00038075035440200656, 'portfolio_value': 0.47974544654652834, 'weights_q0.25': 0.023458148978927472, 'weights_q0.5': 0.02845278992972488, 'weights_q0.75': 0.046388686708742986, 'weights_max': 0.07653234220880864, 'weights_std': 0.017791149291582296}
# ---------------------------------
# | time/              |          |
# |    episodes        | 35       |
# |    fps             | 132      |
# |    time_elapsed    | 332      |
# |    total_timesteps | 44100    |
# | train/             |          |
# |    actor_loss      | -6.24    |
# |    critic_loss     | 0.000197 |
# |    ent_coef        | 3.03e-05 |
# |    ent_coef_loss   | 26.5     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0972   |
# |    mean_reward     | 0.000374 |
# |    min_reward      | -0.184   |
# |    n_updates       | 43999    |
# |    portfolio_value | 0.471    |
# ---------------------------------
# {'min_reward': -0.17270072553927607, 'max_reward': 0.12652861005920013, 'mean_reward': 0.0004219789284768434, 'portfolio_value': 0.5316934498808233, 'weights_q0.25': 0.02786504943401195, 'weights_q0.5': 0.038329386327603104, 'weights_q0.75': 0.04192355800337967, 'weights_max': 0.06358151216273937, 'weights_std': 0.012884844346469512}
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 132      |
# |    time_elapsed    | 341      |
# |    total_timesteps | 45360    |
# | train/             |          |
# |    actor_loss      | -5.49    |
# |    critic_loss     | 0.000292 |
# |    ent_coef        | 3.49e-05 |
# |    ent_coef_loss   | -19.3    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.127    |
# |    mean_reward     | 0.000415 |
# |    min_reward      | -0.173   |
# |    n_updates       | 45259    |
# |    portfolio_value | 0.523    |
# ---------------------------------
# {'min_reward': -0.1847251193201035, 'max_reward': 0.1261287602780347, 'mean_reward': 0.0004240401513831691, 'portfolio_value': 0.5342905907427936, 'weights_q0.25': 0.0239575994655211, 'weights_q0.5': 0.03829726706397728, 'weights_q0.75': 0.04739665038164188, 'weights_max': 0.061107547998346584, 'weights_std': 0.015168599417948167}
# ---------------------------------
# | time/              |          |
# |    episodes        | 37       |
# |    fps             | 132      |
# |    time_elapsed    | 351      |
# |    total_timesteps | 46620    |
# | train/             |          |
# |    actor_loss      | -5.2     |
# |    critic_loss     | 0.000118 |
# |    ent_coef        | 4.19e-05 |
# |    ent_coef_loss   | -43.1    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.126    |
# |    mean_reward     | 0.000419 |
# |    min_reward      | -0.185   |
# |    n_updates       | 46519    |
# |    portfolio_value | 0.528    |
# ---------------------------------
# {'min_reward': -0.17998635435069274, 'max_reward': 0.14132002507566394, 'mean_reward': 0.00039179369614179247, 'portfolio_value': 0.4936600571386584, 'weights_q0.25': 0.018798378603668398, 'weights_q0.5': 0.027678985733717937, 'weights_q0.75': 0.05136382904661879, 'weights_max': 0.0704697900307734, 'weights_std': 0.019121752321618765}
# ---------------------------------
# | time/              |          |
# |    episodes        | 38       |
# |    fps             | 132      |
# |    time_elapsed    | 361      |
# |    total_timesteps | 47880    |
# | train/             |          |
# |    actor_loss      | -4.87    |
# |    critic_loss     | 0.000453 |
# |    ent_coef        | 2.74e-05 |
# |    ent_coef_loss   | -16.4    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.141    |
# |    mean_reward     | 0.000386 |
# |    min_reward      | -0.18    |
# |    n_updates       | 47779    |
# |    portfolio_value | 0.486    |
# ---------------------------------
# {'min_reward': -0.18374566867652783, 'max_reward': 0.12082281544784554, 'mean_reward': 0.0003793308890742669, 'portfolio_value': 0.4779569202335762, 'weights_q0.25': 0.020732979202368364, 'weights_q0.5': 0.03835180040318325, 'weights_q0.75': 0.04458408315649612, 'weights_max': 0.0726546125838689, 'weights_std': 0.015346211117479242}
# ---------------------------------
# | time/              |          |
# |    episodes        | 39       |
# |    fps             | 132      |
# |    time_elapsed    | 370      |
# |    total_timesteps | 49140    |
# | train/             |          |
# |    actor_loss      | -4.25    |
# |    critic_loss     | 0.00158  |
# |    ent_coef        | 2.83e-05 |
# |    ent_coef_loss   | -36.7    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.121    |
# |    mean_reward     | 0.000374 |
# |    min_reward      | -0.184   |
# |    n_updates       | 49039    |
# |    portfolio_value | 0.47     |
# ---------------------------------
# {'min_reward': -0.17622645092393294, 'max_reward': 0.1244833489104429, 'mean_reward': 0.0003895922025481192, 'portfolio_value': 0.4908861752106302, 'weights_q0.25': 0.016969563710429913, 'weights_q0.5': 0.033434577578248026, 'weights_q0.75': 0.0514475598378844, 'weights_max': 0.07612704531843172, 'weights_std': 0.018842084090689652}
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 132      |
# |    time_elapsed    | 380      |
# |    total_timesteps | 50400    |
# | train/             |          |
# |    actor_loss      | -3.78    |
# |    critic_loss     | 8.02e-05 |
# |    ent_coef        | 2.73e-05 |
# |    ent_coef_loss   | -97.7    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.124    |
# |    mean_reward     | 0.000386 |
# |    min_reward      | -0.176   |
# |    n_updates       | 50299    |
# |    portfolio_value | 0.486    |
# ---------------------------------
# {'min_reward': -0.17162169794520699, 'max_reward': 0.09364326202079376, 'mean_reward': 0.0004078279599631075, 'portfolio_value': 0.5138632295535153, 'weights_q0.25': 0.021079920034023984, 'weights_q0.5': 0.03516039276948233, 'weights_q0.75': 0.051025663941299024, 'weights_max': 0.06767174333178055, 'weights_std': 0.01681024123846788}
# ---------------------------------
# | time/              |          |
# |    episodes        | 41       |
# |    fps             | 132      |
# |    time_elapsed    | 389      |
# |    total_timesteps | 51660    |
# | train/             |          |
# |    actor_loss      | -4.05    |
# |    critic_loss     | 0.000352 |
# |    ent_coef        | 2.25e-05 |
# |    ent_coef_loss   | -57.5    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0936   |
# |    mean_reward     | 0.0004   |
# |    min_reward      | -0.172   |
# |    n_updates       | 51559    |
# |    portfolio_value | 0.503    |
# ---------------------------------
# {'min_reward': -0.17654753934362552, 'max_reward': 0.09350678824599794, 'mean_reward': 0.00034509371918907595, 'portfolio_value': 0.43481808617823603, 'weights_q0.25': 0.025004703657775004, 'weights_q0.5': 0.037392724916373854, 'weights_q0.75': 0.046114221013104785, 'weights_max': 0.06116338852532688, 'weights_std': 0.013674653620748201}
# ---------------------------------
# | time/              |          |
# |    episodes        | 42       |
# |    fps             | 132      |
# |    time_elapsed    | 398      |
# |    total_timesteps | 52920    |
# | train/             |          |
# |    actor_loss      | -3.28    |
# |    critic_loss     | 6.76e-05 |
# |    ent_coef        | 1.78e-05 |
# |    ent_coef_loss   | -80.3    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0935   |
# |    mean_reward     | 0.000342 |
# |    min_reward      | -0.177   |
# |    n_updates       | 52819    |
# |    portfolio_value | 0.43     |
# ---------------------------------
# {'min_reward': -0.1748666335815415, 'max_reward': 0.1236573671086388, 'mean_reward': 0.0004936674418074196, 'portfolio_value': 0.6220209766773493, 'weights_q0.25': 0.022928533058124402, 'weights_q0.5': 0.03375092635027035, 'weights_q0.75': 0.04910991271772996, 'weights_max': 0.05984083328292338, 'weights_std': 0.014717198005306244}
# ---------------------------------
# | time/              |          |
# |    episodes        | 43       |
# |    fps             | 132      |
# |    time_elapsed    | 408      |
# |    total_timesteps | 54180    |
# | train/             |          |
# |    actor_loss      | -3.27    |
# |    critic_loss     | 5.51e-05 |
# |    ent_coef        | 1.65e-05 |
# |    ent_coef_loss   | -58.3    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.124    |
# |    mean_reward     | 0.000488 |
# |    min_reward      | -0.175   |
# |    n_updates       | 54079    |
# |    portfolio_value | 0.615    |
# ---------------------------------
# {'min_reward': -0.17537871359195523, 'max_reward': 0.17639276093622577, 'mean_reward': 0.0006227694616927313, 'portfolio_value': 0.7846895217328409, 'weights_q0.25': 0.019930207367470202, 'weights_q0.5': 0.03563901686455401, 'weights_q0.75': 0.05000249363736037, 'weights_max': 0.06521306759518862, 'weights_std': 0.017453093129914877}
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 132      |
# |    time_elapsed    | 417      |
# |    total_timesteps | 55440    |
# | train/             |          |
# |    actor_loss      | -3.34    |
# |    critic_loss     | 0.000183 |
# |    ent_coef        | 1.94e-05 |
# |    ent_coef_loss   | -70.4    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.176    |
# |    mean_reward     | 0.000618 |
# |    min_reward      | -0.175   |
# |    n_updates       | 55339    |
# |    portfolio_value | 0.778    |
# ---------------------------------
# {'min_reward': -0.17813061223891108, 'max_reward': 0.18548935961085927, 'mean_reward': 0.0005216062840621916, 'portfolio_value': 0.6572239179183613, 'weights_q0.25': 0.017226626746869596, 'weights_q0.5': 0.037731437729888365, 'weights_q0.75': 0.049661260978802316, 'weights_max': 0.06681473031768961, 'weights_std': 0.01687817255196773}
# ---------------------------------
# | time/              |          |
# |    episodes        | 45       |
# |    fps             | 132      |
# |    time_elapsed    | 427      |
# |    total_timesteps | 56700    |
# | train/             |          |
# |    actor_loss      | -3.2     |
# |    critic_loss     | 0.000165 |
# |    ent_coef        | 1.63e-05 |
# |    ent_coef_loss   | 143      |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.185    |
# |    mean_reward     | 0.000516 |
# |    min_reward      | -0.178   |
# |    n_updates       | 56599    |
# |    portfolio_value | 0.649    |
# ---------------------------------
# {'min_reward': -0.1736821187467131, 'max_reward': 0.1811198535250156, 'mean_reward': 0.000638724708357461, 'portfolio_value': 0.8047931325304012, 'weights_q0.25': 0.023594662124204108, 'weights_q0.5': 0.034944964001319925, 'weights_q0.75': 0.049388422691268356, 'weights_max': 0.06409936268122089, 'weights_std': 0.01626506933720104}
# ---------------------------------
# | time/              |          |
# |    episodes        | 46       |
# |    fps             | 132      |
# |    time_elapsed    | 436      |
# |    total_timesteps | 57960    |
# | train/             |          |
# |    actor_loss      | -2.51    |
# |    critic_loss     | 0.000212 |
# |    ent_coef        | 2.28e-05 |
# |    ent_coef_loss   | 42.7     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.181    |
# |    mean_reward     | 0.000634 |
# |    min_reward      | -0.174   |
# |    n_updates       | 57859    |
# |    portfolio_value | 0.798    |
# ---------------------------------
# {'min_reward': -0.17473884635974507, 'max_reward': 0.16937414810790002, 'mean_reward': 0.00047430474386697853, 'portfolio_value': 0.597623977272392, 'weights_q0.25': 0.021992111891311075, 'weights_q0.5': 0.03250450257502931, 'weights_q0.75': 0.053061467635980214, 'weights_max': 0.05797258818719327, 'weights_std': 0.01631554780821509}
# ---------------------------------
# | time/              |          |
# |    episodes        | 47       |
# |    fps             | 132      |
# |    time_elapsed    | 446      |
# |    total_timesteps | 59220    |
# | train/             |          |
# |    actor_loss      | -2.53    |
# |    critic_loss     | 6.89e-05 |
# |    ent_coef        | 2e-05    |
# |    ent_coef_loss   | -54.2    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.169    |
# |    mean_reward     | 0.00047  |
# |    min_reward      | -0.175   |
# |    n_updates       | 59119    |
# |    portfolio_value | 0.591    |
# ---------------------------------
# {'min_reward': -0.16279691219919612, 'max_reward': 0.1663624468678606, 'mean_reward': 0.0005249328409601935, 'portfolio_value': 0.6614153796098439, 'weights_q0.25': 0.020499921754835455, 'weights_q0.5': 0.03703216299283421, 'weights_q0.75': 0.05252548852146968, 'weights_max': 0.06116361239180721, 'weights_std': 0.01696418167642589}
# ---------------------------------
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 132      |
# |    time_elapsed    | 455      |
# |    total_timesteps | 60480    |
# | train/             |          |
# |    actor_loss      | -2.18    |
# |    critic_loss     | 3.7e-05  |
# |    ent_coef        | 1.53e-05 |
# |    ent_coef_loss   | -97.3    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.166    |
# |    mean_reward     | 0.000521 |
# |    min_reward      | -0.163   |
# |    n_updates       | 60379    |
# |    portfolio_value | 0.655    |
# ---------------------------------
# {'min_reward': -0.16405003595601383, 'max_reward': 0.168980314205468, 'mean_reward': 0.0007197616570520009, 'portfolio_value': 0.9068996878855216, 'weights_q0.25': 0.016258481342909258, 'weights_q0.5': 0.03667788914766776, 'weights_q0.75': 0.04894152964109154, 'weights_max': 0.07400004265048632, 'weights_std': 0.017958100489118046}
# ---------------------------------
# | time/              |          |
# |    episodes        | 49       |
# |    fps             | 132      |
# |    time_elapsed    | 465      |
# |    total_timesteps | 61740    |
# | train/             |          |
# |    actor_loss      | -2.32    |
# |    critic_loss     | 4.13e-05 |
# |    ent_coef        | 1.55e-05 |
# |    ent_coef_loss   | -81.8    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.169    |
# |    mean_reward     | 0.000713 |
# |    min_reward      | -0.164   |
# |    n_updates       | 61639    |
# |    portfolio_value | 0.897    |
# ---------------------------------
# {'min_reward': -0.16258078003816817, 'max_reward': 0.14203147641974148, 'mean_reward': 0.0006754319577077379, 'portfolio_value': 0.851044266711749, 'weights_q0.25': 0.0202237309414147, 'weights_q0.5': 0.040713609654557836, 'weights_q0.75': 0.049147992751410706, 'weights_max': 0.06339165302763013, 'weights_std': 0.017275141768025533}
# ---------------------------------
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 132      |
# |    time_elapsed    | 475      |
# |    total_timesteps | 63000    |
# | train/             |          |
# |    actor_loss      | -2.02    |
# |    critic_loss     | 0.000194 |
# |    ent_coef        | 1.73e-05 |
# |    ent_coef_loss   | -11      |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.142    |
# |    mean_reward     | 0.000672 |
# |    min_reward      | -0.163   |
# |    n_updates       | 62899    |
# |    portfolio_value | 0.846    |
# ---------------------------------
# {'min_reward': -0.1638754717166644, 'max_reward': 0.1822102846069124, 'mean_reward': 0.0007816930488986455, 'portfolio_value': 0.9849332416122955, 'weights_q0.25': 0.01686386957182767, 'weights_q0.5': 0.0309758905954702, 'weights_q0.75': 0.04835658034818811, 'weights_max': 0.07763417076020881, 'weights_std': 0.022000454554837127}
# ---------------------------------
# | time/              |          |
# |    episodes        | 51       |
# |    fps             | 132      |
# |    time_elapsed    | 484      |
# |    total_timesteps | 64260    |
# ...
# ---------------------------------
# | time/              |          |
# |    episodes        | 103      |
# |    fps             | 134      |
# |    time_elapsed    | 962      |
# |    total_timesteps | 129780   |
# | train/             |          |
# |    actor_loss      | -0.225   |
# |    critic_loss     | 5.27e-06 |
# |    ent_coef        | 1.15e-05 |
# |    ent_coef_loss   | -10.6    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.206    |
# |    mean_reward     | 0.00291  |
# |    min_reward      | -0.151   |
# |    n_updates       | 129679   |
# |    portfolio_value | 3.66     |
# ---------------------------------
# {'min_reward': -0.15157637912871325, 'max_reward': 0.20193521128098424, 'mean_reward': 0.0030214843578525662, 'portfolio_value': 3.8070702908942335, 'weights_q0.25': 0.010315744792700515, 'weights_q0.5': 0.019718575736607562, 'weights_q0.75': 0.06886641000370256, 'weights_max': 0.0747246447460177, 'weights_std': 0.027443597689349713}
# ---------------------------------
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 134      |
# |    time_elapsed    | 970      |
# |    total_timesteps | 131040   |
# | train/             |          |
# |    actor_loss      | -0.267   |
# |    critic_loss     | 5.04e-06 |
# |    ent_coef        | 1.12e-05 |
# |    ent_coef_loss   | -16.9    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.202    |
# |    mean_reward     | 0.00303  |
# |    min_reward      | -0.152   |
# |    n_updates       | 130939   |
# |    portfolio_value | 3.81     |
# ---------------------------------
# {'min_reward': -0.1507642691783021, 'max_reward': 0.20663148306838608, 'mean_reward': 0.0030300327635626473, 'portfolio_value': 3.817841282088938, 'weights_q0.25': 0.010955272653932232, 'weights_q0.5': 0.0239808232482992, 'weights_q0.75': 0.06113751969072491, 'weights_max': 0.08068172362715621, 'weights_std': 0.027253030344207656}
# ---------------------------------
# | time/              |          |
# |    episodes        | 105      |
# |    fps             | 134      |
# |    time_elapsed    | 980      |
# |    total_timesteps | 132300   |
# | train/             |          |
# |    actor_loss      | -0.242   |
# |    critic_loss     | 4.55e-06 |
# |    ent_coef        | 1.17e-05 |
# |    ent_coef_loss   | -32.9    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.207    |
# |    mean_reward     | 0.00304  |
# |    min_reward      | -0.151   |
# |    n_updates       | 132199   |
# |    portfolio_value | 3.82     |
# ---------------------------------
# {'min_reward': -0.1496531413700438, 'max_reward': 0.20667241832967898, 'mean_reward': 0.0031195664814767537, 'portfolio_value': 3.9306537666607104, 'weights_q0.25': 0.010029607084453426, 'weights_q0.5': 0.023747777233468163, 'weights_q0.75': 0.0680900000197496, 'weights_max': 0.07500462798866689, 'weights_std': 0.02656536423957935}
# ---------------------------------
# | time/              |          |
# |    episodes        | 106      |
# |    fps             | 134      |
# |    time_elapsed    | 989      |
# |    total_timesteps | 133560   |
# | train/             |          |
# |    actor_loss      | -0.224   |
# |    critic_loss     | 4.51e-06 |
# |    ent_coef        | 1.16e-05 |
# |    ent_coef_loss   | 1.61     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.207    |
# |    mean_reward     | 0.00312  |
# |    min_reward      | -0.15    |
# |    n_updates       | 133459   |
# |    portfolio_value | 3.93     |
# ---------------------------------
# {'min_reward': -0.15084547790081324, 'max_reward': 0.2064957353115707, 'mean_reward': 0.0030693760555972386, 'portfolio_value': 3.8674138300525174, 'weights_q0.25': 0.010393350871004695, 'weights_q0.5': 0.03300707597599489, 'weights_q0.75': 0.061546034408972806, 'weights_max': 0.07045496895188842, 'weights_std': 0.024322757513425233}
# ---------------------------------
# | time/              |          |
# |    episodes        | 107      |
# |    fps             | 134      |
# |    time_elapsed    | 999      |
# |    total_timesteps | 134820   |
# | train/             |          |
# |    actor_loss      | -0.233   |
# |    critic_loss     | 2.15e-06 |
# |    ent_coef        | 1.15e-05 |
# |    ent_coef_loss   | -15      |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.206    |
# |    mean_reward     | 0.00307  |
# |    min_reward      | -0.151   |
# |    n_updates       | 134719   |
# |    portfolio_value | 3.87     |
# ---------------------------------
# {'min_reward': -0.15522333095351226, 'max_reward': 0.20517959052171225, 'mean_reward': 0.0031799906985699174, 'portfolio_value': 4.006788280198095, 'weights_q0.25': 0.01041762742471661, 'weights_q0.5': 0.02421630117310186, 'weights_q0.75': 0.0622320807821818, 'weights_max': 0.07605461411441974, 'weights_std': 0.025884974174327807}
# ---------------------------------
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 134      |
# |    time_elapsed    | 1008     |
# |    total_timesteps | 136080   |
# | train/             |          |
# |    actor_loss      | -0.243   |
# |    critic_loss     | 9.66e-06 |
# |    ent_coef        | 1.15e-05 |
# |    ent_coef_loss   | 38.7     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.205    |
# |    mean_reward     | 0.00319  |
# |    min_reward      | -0.155   |
# |    n_updates       | 135979   |
# |    portfolio_value | 4.01     |
# ---------------------------------
# {'min_reward': -0.15723847207131708, 'max_reward': 0.20682796125848804, 'mean_reward': 0.0030969816821295195, 'portfolio_value': 3.9021969194831927, 'weights_q0.25': 0.013357503530440865, 'weights_q0.5': 0.025289437560607888, 'weights_q0.75': 0.0592321564441895, 'weights_max': 0.07778071011439174, 'weights_std': 0.024697629020929583}
# ---------------------------------
# | time/              |          |
# |    episodes        | 109      |
# |    fps             | 134      |
# |    time_elapsed    | 1018     |
# |    total_timesteps | 137340   |
# | train/             |          |
# |    actor_loss      | -0.247   |
# |    critic_loss     | 5.31e-06 |
# |    ent_coef        | 1.11e-05 |
# |    ent_coef_loss   | -1.17    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.207    |
# |    mean_reward     | 0.0031   |
# |    min_reward      | -0.157   |
# |    n_updates       | 137239   |
# |    portfolio_value | 3.9      |
# ---------------------------------
# {'min_reward': -0.1568534224981808, 'max_reward': 0.20829063005969384, 'mean_reward': 0.0030781824223199464, 'portfolio_value': 3.878509852123132, 'weights_q0.25': 0.01045971976296493, 'weights_q0.5': 0.025944206544306035, 'weights_q0.75': 0.06291542237348749, 'weights_max': 0.0662649837311772, 'weights_std': 0.024133348801622264}
# ---------------------------------
# | time/              |          |
# |    episodes        | 110      |
# |    fps             | 134      |
# |    time_elapsed    | 1027     |
# |    total_timesteps | 138600   |
# | train/             |          |
# |    actor_loss      | -0.241   |
# |    critic_loss     | 2.33e-06 |
# |    ent_coef        | 1.1e-05  |
# |    ent_coef_loss   | 33.1     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.208    |
# |    mean_reward     | 0.00308  |
# |    min_reward      | -0.157   |
# |    n_updates       | 138499   |
# |    portfolio_value | 3.88     |
# ---------------------------------
# {'min_reward': -0.16118245701699965, 'max_reward': 0.207004118671654, 'mean_reward': 0.0030928351673791977, 'portfolio_value': 3.8969723108977914, 'weights_q0.25': 0.010682815820884154, 'weights_q0.5': 0.03753038667504842, 'weights_q0.75': 0.06307319056897806, 'weights_max': 0.07094555793670168, 'weights_std': 0.024208932834069607}
# ---------------------------------
# | time/              |          |
# |    episodes        | 111      |
# |    fps             | 134      |
# |    time_elapsed    | 1036     |
# |    total_timesteps | 139860   |
# | train/             |          |
# |    actor_loss      | -0.256   |
# |    critic_loss     | 5.51e-06 |
# |    ent_coef        | 1.14e-05 |
# |    ent_coef_loss   | 7.34     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.207    |
# |    mean_reward     | 0.0031   |
# |    min_reward      | -0.161   |
# |    n_updates       | 139759   |
# |    portfolio_value | 3.9      |
# ---------------------------------
# {'min_reward': -0.15329726282852796, 'max_reward': 0.20636616555044185, 'mean_reward': 0.003141570983273072, 'portfolio_value': 3.9583794389240685, 'weights_q0.25': 0.010031623093352681, 'weights_q0.5': 0.027337666467359887, 'weights_q0.75': 0.06270654914295708, 'weights_max': 0.07133118053666972, 'weights_std': 0.024878462744875134}
# ---------------------------------
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 134      |
# |    time_elapsed    | 1046     |
# |    total_timesteps | 141120   |
# | train/             |          |
# |    actor_loss      | -0.232   |
# |    critic_loss     | 6.27e-06 |
# |    ent_coef        | 1.12e-05 |
# |    ent_coef_loss   | -15.7    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.206    |
# |    mean_reward     | 0.00315  |
# |    min_reward      | -0.153   |
# |    n_updates       | 141019   |
# |    portfolio_value | 3.96     |
# ---------------------------------
# {'min_reward': -0.15286654612034978, 'max_reward': 0.19638047285996407, 'mean_reward': 0.003114256251489457, 'portfolio_value': 3.923962876876713, 'weights_q0.25': 0.009946195626867715, 'weights_q0.5': 0.03189908365341624, 'weights_q0.75': 0.060186783913934006, 'weights_max': 0.06922142497534645, 'weights_std': 0.024301036221320856}
# ---------------------------------
# | time/              |          |
# |    episodes        | 113      |
# |    fps             | 134      |
# |    time_elapsed    | 1055     |
# |    total_timesteps | 142380   |
# | train/             |          |
# |    actor_loss      | -0.251   |
# |    critic_loss     | 2.55e-06 |
# |    ent_coef        | 1.11e-05 |
# |    ent_coef_loss   | 7.96     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.196    |
# |    mean_reward     | 0.00312  |
# |    min_reward      | -0.153   |
# |    n_updates       | 142279   |
# |    portfolio_value | 3.93     |
# ---------------------------------
# {'min_reward': -0.1552243106653372, 'max_reward': 0.11549147471922692, 'mean_reward': 0.002920801735354732, 'portfolio_value': 3.680210186546962, 'weights_q0.25': 0.011934528450348886, 'weights_q0.5': 0.028020741855901376, 'weights_q0.75': 0.052613365665381016, 'weights_max': 0.08149336137530672, 'weights_std': 0.024649372532578373}
# ---------------------------------
# | time/              |          |
# |    episodes        | 114      |
# |    fps             | 135      |
# |    time_elapsed    | 1063     |
# |    total_timesteps | 143640   |
# | train/             |          |
# |    actor_loss      | -0.258   |
# |    critic_loss     | 1.12e-05 |
# |    ent_coef        | 1.14e-05 |
# |    ent_coef_loss   | 4.03     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.115    |
# |    mean_reward     | 0.00292  |
# |    min_reward      | -0.155   |
# |    n_updates       | 143539   |
# |    portfolio_value | 3.68     |
# ---------------------------------
# {'min_reward': -0.15150339730250445, 'max_reward': 0.19166211087441698, 'mean_reward': 0.003138032771812178, 'portfolio_value': 3.9539212924833467, 'weights_q0.25': 0.011472630503006086, 'weights_q0.5': 0.026395169679883736, 'weights_q0.75': 0.06480068571807615, 'weights_max': 0.07345299409728838, 'weights_std': 0.025203758757733633}
# ---------------------------------
# | time/              |          |
# |    episodes        | 115      |
# |    fps             | 135      |
# |    time_elapsed    | 1072     |
# |    total_timesteps | 144900   |
# | train/             |          |
# |    actor_loss      | -0.258   |
# |    critic_loss     | 6.71e-06 |
# |    ent_coef        | 1.11e-05 |
# |    ent_coef_loss   | 19.6     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.192    |
# |    mean_reward     | 0.00314  |
# |    min_reward      | -0.152   |
# |    n_updates       | 144799   |
# |    portfolio_value | 3.96     |
# ---------------------------------
# {'min_reward': -0.15273087550223863, 'max_reward': 0.2048335649416024, 'mean_reward': 0.003147869504977318, 'portfolio_value': 3.9663155762714206, 'weights_q0.25': 0.01224255765058622, 'weights_q0.5': 0.032733599375104006, 'weights_q0.75': 0.05956378228793439, 'weights_max': 0.07406896281908797, 'weights_std': 0.023971256689344026}
# ---------------------------------
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 135      |
# |    time_elapsed    | 1081     |
# |    total_timesteps | 146160   |
# | train/             |          |
# |    actor_loss      | -0.248   |
# |    critic_loss     | 5.56e-06 |
# |    ent_coef        | 1.05e-05 |
# |    ent_coef_loss   | -36.4    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.205    |
# |    mean_reward     | 0.00315  |
# |    min_reward      | -0.153   |
# |    n_updates       | 146059   |
# |    portfolio_value | 3.97     |
# ---------------------------------
# {'min_reward': -0.149503820972201, 'max_reward': 0.20691499580181794, 'mean_reward': 0.003201468949485879, 'portfolio_value': 4.033850876352208, 'weights_q0.25': 0.011032611846622105, 'weights_q0.5': 0.03451265592828605, 'weights_q0.75': 0.05816403949278387, 'weights_max': 0.06702146821307939, 'weights_std': 0.02205719387765062}
# ---------------------------------
# | time/              |          |
# |    episodes        | 117      |
# |    fps             | 135      |
# |    time_elapsed    | 1090     |
# |    total_timesteps | 147420   |
# | train/             |          |
# |    actor_loss      | -0.259   |
# |    critic_loss     | 4.38e-06 |
# |    ent_coef        | 1.1e-05  |
# |    ent_coef_loss   | -9.09    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.207    |
# |    mean_reward     | 0.00321  |
# |    min_reward      | -0.15    |
# |    n_updates       | 147319   |
# |    portfolio_value | 4.04     |
# ---------------------------------
# {'min_reward': -0.15143566937644126, 'max_reward': 0.20675489053806198, 'mean_reward': 0.00328807773730698, 'portfolio_value': 4.142977949006797, 'weights_q0.25': 0.010930639477993182, 'weights_q0.5': 0.025832406966625525, 'weights_q0.75': 0.0634993178762739, 'weights_max': 0.07523004119948225, 'weights_std': 0.024923456300297974}
# ---------------------------------
# | time/              |          |
# |    episodes        | 118      |
# |    fps             | 135      |
# |    time_elapsed    | 1099     |
# |    total_timesteps | 148680   |
# | train/             |          |
# |    actor_loss      | -0.272   |
# |    critic_loss     | 5.43e-06 |
# |    ent_coef        | 1.1e-05  |
# |    ent_coef_loss   | -15.1    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.207    |
# |    mean_reward     | 0.00329  |
# |    min_reward      | -0.151   |
# |    n_updates       | 148579   |
# |    portfolio_value | 4.15     |
# ---------------------------------
# {'min_reward': -0.15388075259987127, 'max_reward': 0.20591192147887205, 'mean_reward': 0.0031857034198440534, 'portfolio_value': 4.013986309003509, 'weights_q0.25': 0.01374520782929494, 'weights_q0.5': 0.03154101408944092, 'weights_q0.75': 0.05577793712321944, 'weights_max': 0.0744673429414178, 'weights_std': 0.022489091591756757}
# ---------------------------------
# | time/              |          |
# |    episodes        | 119      |
# |    fps             | 135      |
# |    time_elapsed    | 1108     |
# |    total_timesteps | 149940   |
# | train/             |          |
# |    actor_loss      | -0.254   |
# |    critic_loss     | 2.53e-06 |
# |    ent_coef        | 1.12e-05 |
# |    ent_coef_loss   | -4.44    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.206    |
# |    mean_reward     | 0.00319  |
# |    min_reward      | -0.154   |
# |    n_updates       | 149839   |
# |    portfolio_value | 4.01     |
# ---------------------------------

# %% [markdown]
# #### Saving model and running mean from env

# %%
model.save('models/' + model_name)
with open('models/' + model_name + '_obs_rms.pickle', 'wb') as handle:
    pickle.dump(train_env.obs_rms, handle)

# %% [markdown]
# ## Evaluation

# %%
mean_reward, std_reward = evaluate_policy(model, train_env, n_eval_episodes=5, deterministic=False, warn=False, return_episode_rewards=False)
print(mean_reward, std_reward)
# Out:
# {'min_reward': -0.1551756418967425, 'max_reward': 0.2051501027367493, 'mean_reward': 0.0031182704246739334, 'portfolio_value': 3.9290207350891557, 'weights_q0.25': 0.012947083196902343, 'weights_q0.5': 0.02831708697868826, 'weights_q0.75': 0.06261019890797306, 'weights_max': 0.07241900651081343, 'weights_std': 0.023459503237995828}
# {'min_reward': -0.15261769454163304, 'max_reward': 0.2067505208626652, 'mean_reward': 0.0031151472645706093, 'portfolio_value': 3.9250855533589637, 'weights_q0.25': 0.011957855735723659, 'weights_q0.5': 0.023034958578173094, 'weights_q0.75': 0.06179814493697238, 'weights_max': 0.06960267782515266, 'weights_std': 0.024291828874461626}
# {'min_reward': -0.1558077356194606, 'max_reward': 0.2057931701088344, 'mean_reward': 0.003103618810809518, 'portfolio_value': 3.9105597016199978, 'weights_q0.25': 0.013518319494265381, 'weights_q0.5': 0.02403929192007034, 'weights_q0.75': 0.0625736048484683, 'weights_max': 0.07221934615278286, 'weights_std': 0.023597901522330263}
# {'min_reward': -0.15602281915579524, 'max_reward': 0.206046187098488, 'mean_reward': 0.003090738164612721, 'portfolio_value': 3.8943300874120292, 'weights_q0.25': 0.011339843956047391, 'weights_q0.5': 0.03796492147610378, 'weights_q0.75': 0.06000663309399026, 'weights_max': 0.06611584686816623, 'weights_std': 0.022304349607803056}
# {'min_reward': -0.1561554402537531, 'max_reward': 0.20652975639206872, 'mean_reward': 0.003111264323777839, 'portfolio_value': 3.92019304796008, 'weights_q0.25': 0.010307512922548489, 'weights_q0.5': 0.04084531877492793, 'weights_q0.75': 0.05597973125967974, 'weights_max': 0.06476738415215771, 'weights_std': 0.02172966940061143}
# 3.915837836070159 0.012399351794641649

# %%
train_env.venv.venv.envs[0].__dict__.keys()
# Out:
# dict_keys(['data', 'stock_dim', 'close_prices_pct', 'tickers', 'n_assets', 'objective', 'risk_measure', 'rewards_memory', 'actions_memory', 'portfolio_value', 'observations_range', 'current_step', 'weights', 'reward_range', 'action_space', 'observation_space'])

# %%
train_env.training = False
train_env.venv.venv.envs[0].observations_range = (0, 1760) # change to use the test period

# %%
import copy

obs = train_env.reset()
weights_states = [train_env.venv.venv.envs[0].weights]
portfolio_values = [0]
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = train_env.step(action)
    if done:
        break
    else:
        weights_states.append(copy.deepcopy(train_env.venv.venv.envs[0].weights))
        portfolio_values.append(train_env.venv.venv.envs[0].portfolio_value)
        print(train_env.render())
len(portfolio_values), len(weights_states)
# Out:
# {'min_reward': -0.004746610762858191, 'max_reward': -0.004746610762858191, 'mean_reward': -0.004746610762858191, 'portfolio_value': -0.004746610762858191, 'weights_q0.25': 0.012425719301477869, 'weights_q0.5': 0.028633291510034624, 'weights_q0.75': 0.06033297567917744, 'weights_max': 0.0743449346773447, 'weights_std': 0.02318512511726389}
# {'min_reward': -0.021275502604930344, 'max_reward': -0.004746610762858191, 'mean_reward': -0.013011056683894268, 'portfolio_value': -0.026022113367788535, 'weights_q0.25': 0.013377119957668228, 'weights_q0.5': 0.031773963374719216, 'weights_q0.75': 0.05709768210254099, 'weights_max': 0.06952922760609104, 'weights_std': 0.022144421160463296}
# {'min_reward': -0.021275502604930344, 'max_reward': -0.004746610762858191, 'mean_reward': -0.011356544208212463, 'portfolio_value': -0.034069632624637386, 'weights_q0.25': 0.012924303139651544, 'weights_q0.5': 0.029190664871458286, 'weights_q0.75': 0.06026878612609565, 'weights_max': 0.07495704238045953, 'weights_std': 0.023314617475023787}
# {'min_reward': -0.021275502604930344, 'max_reward': 0.008622294952486998, 'mean_reward': -0.006361834418037597, 'portfolio_value': -0.025447337672150388, 'weights_q0.25': 0.013092768911295403, 'weights_q0.5': 0.01632204237702487, 'weights_q0.75': 0.06810789418303573, 'weights_max': 0.09093068386879169, 'weights_std': 0.029989437284980946}
# {'min_reward': -0.021275502604930344, 'max_reward': 0.008622294952486998, 'mean_reward': -0.006459029021496582, 'portfolio_value': -0.03229514510748291, 'weights_q0.25': 0.012609702086612693, 'weights_q0.5': 0.036048521686332866, 'weights_q0.75': 0.053387667460803534, 'weights_max': 0.07306125106381232, 'weights_std': 0.022650818107591203}

# {'min_reward': -0.15280873134165546, 'max_reward': 0.20630300645779137, 'mean_reward': 0.002252675231456547, 'portfolio_value': 3.95119235597479, 'weights_q0.25': 0.016886173234453093, 'weights_q0.5': 0.028569694625914424, 'weights_q0.75': 0.05059012714783234, 'weights_max': 0.07769085666889129, 'weights_std': 0.021608629640365827}
# {'min_reward': -0.15280873134165546, 'max_reward': 0.20630300645779137, 'mean_reward': 0.0022497345534956744, 'portfolio_value': 3.9482841413849146, 'weights_q0.25': 0.014153637031834343, 'weights_q0.5': 0.030006410650421284, 'weights_q0.75': 0.050585958065663426, 'weights_max': 0.08860770730738181, 'weights_std': 0.0239433240237194}
# {'min_reward': -0.15280873134165546, 'max_reward': 0.20630300645779137, 'mean_reward': 0.0022536461920428575, 'portfolio_value': 3.957402713227264, 'weights_q0.25': 0.016250530815303525, 'weights_q0.5': 0.023012076372268334, 'weights_q0.75': 0.046431195784840736, 'weights_max': 0.09562861192914442, 'weights_std': 0.02587445633719945}
# {'min_reward': -0.15280873134165546, 'max_reward': 0.20630300645779137, 'mean_reward': 0.002251656248403366, 'portfolio_value': 3.9561600284447196, 'weights_q0.25': 0.01797462736541471, 'weights_q0.5': 0.024663131506365475, 'weights_q0.75': 0.05754251845114652, 'weights_max': 0.08779696477514412, 'weights_std': 0.023140589858996502}
# {'min_reward': -0.15280873134165546, 'max_reward': 0.20630300645779137, 'mean_reward': 0.002240351686918245, 'portfolio_value': 3.9385382656022805, 'weights_q0.25': 0.018211249810945976, 'weights_q0.5': 0.02705486761452485, 'weights_q0.75': 0.049914721522211936, 'weights_max': 0.09203754184195699, 'weights_std': 0.02180102034506281}
# {'min_reward': -0.15280873134165546, 'max_reward': 0.20630300645779137, 'mean_reward': 0.0022504001726970655, 'portfolio_value': 3.958453903774144, 'weights_q0.25': 0.017177437952545, 'weights_q0.5': 0.026099733843624885, 'weights_q0.75': 0.041512006373404825, 'weights_max': 0.1063574213037701, 'weights_std': 0.02511415713454569}
# {'min_reward': -0.15280873134165546, 'max_reward': 0.20630300645779137, 'mean_reward': 0.0022442573624851378, 'portfolio_value': 3.9498929579738484, 'weights_q0.25': 0.015756707263401316, 'weights_q0.5': 0.03031222250343006, 'weights_q0.75': 0.05486201880525693, 'weights_max': 0.07649744631776383, 'weights_std': 0.0222200401895222}
# (1760, 1760)

# %%
portfolio_state = pd.DataFrame(index=train_env.venv.venv.envs[0].close_prices_pct.index, data=portfolio_values)
portfolio_state.to_csv('portfolios/' + model_name + '_portfolio.csv')

# %%
weights_df = pd.DataFrame(index=train_env.venv.venv.envs[0].close_prices_pct.columns, data=weights_states[-1])
weights_df.to_csv('portfolios/' + model_name + '_weights.csv')

# %% [markdown]
# ## Tests

# %%
with open('data/sp500_data_5y.pickle', 'rb') as f:
    data = pickle.load(f)
    close_prices = pd.DataFrame({k: v['Close'] for k, v in data.items()})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[294], line 1
# ----> 1 with open('data/sp500_data_5y.pickle', 'rb') as f:
#       2     data = pickle.load(f)
#       3     close_prices = pd.DataFrame({k: v['Close'] for k, v in data.items()})
#
# File ~/miniconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/sp500_data_5y.pickle'

# %%
data['AAPL'].diff()

# %%
rand_w = softmax_normalization(np.random.randn(489))
rand_w

# %%
ones_w = softmax_normalization(np.ones(489))
ones_w

# %%
close_prices.diff()

# %%
(close_prices.pct_change().iloc[48] @ rand_w)

# %%
close_prices.pct_change().dropna().mean() @ rand_w

# %%
(close_prices.pct_change().dropna() @ rand_w).sum()

# %%
(close_prices.pct_change().dropna() @ ones_w).sum()
