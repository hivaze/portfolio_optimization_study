# %%
import riskfolio as rf

import matplotlib.pyplot as plt
import numpy as np
import pickle
import random

import pandas as pd

import gym
from gym import spaces

from stable_baselines3 import PPO, A2C, TD3, SAC, DDPG, DQN
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, VecFrameStack, SubprocVecEnv
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.evaluation import evaluate_policy

import torch

# %%
def softmax_normalization(actions):
    numerator = np.exp(actions)
    denominator = np.sum(np.exp(actions))
    softmax_output = numerator/denominator
    return softmax_output

# %% [markdown]
# ## Definition of gym Environment

# %%
class PortfolioAllocationEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, data_file,
                 sector = None,
                 objective = 'max_return',
                 risk_measure = 'MV',
                 drop_close = True,
                 observations_range = (0, 1259)):
        """
        Инициализация среды
        """
        super(PortfolioAllocationEnv, self).__init__()

        with open(data_file, 'rb') as f:
            self.data = pickle.load(f)
            if sector is not None:
                self.data = list(filter(lambda stock: stock['sector'] == sector, self.data))
            if drop_close:
                for stock in self.data:
                    stock['data'] = stock['data'].drop(['Close'], axis=1)

        self.stock_dim = self.data[0]['data'].shape[1]

        close_price_changes = {stock['ticker']: stock['data']['Close_Change'] for stock in self.data}
        self.close_prices_pct = pd.DataFrame(close_price_changes)

        self.tickers = [stock['ticker'] for stock in self.data]
        self.n_assets = len(self.data)

        self.objective = objective
        self.risk_measure = risk_measure

        self.rewards_memory = None
        self.actions_memory = None

        self.portfolio_value = 0
        self.observations_range = observations_range
        self.current_step = observations_range[0]

        self.weights = np.ones(self.n_assets) / self.n_assets

        self.reward_range = (-10, 10)
        self.action_space = gym.spaces.Box(low=-1, high=1, shape=(self.n_assets,))
        self.observation_space = gym.spaces.Box(low=-np.inf, high=np.inf, shape=(self.n_assets, self.stock_dim + 1))

    def step(self, action):
        """
        Выполнение одного шага
        """
        # assert self.action_space.contains(action), "Invalid action"

        # Получаем текущее состояние
        state = self._get_state()

        # Вычисляем награду
        reward = self._get_reward(action)

        # Обновляем текущий шаг
        self.current_step += 1

        # Проверяем, достигнут ли конец эпизода
        done = self.current_step >= self.observations_range[1]

        if done:
            print(self.render())

        # Возвращаем состояние, награду и флаг окончания эпизода
        return state, reward, done, {}

    def reset(self):
        """
        Сброс среды в начальное состояние
        """
        self.portfolio_value = 0
        self.rewards_memory = []
        self.current_step = self.observations_range[0]
        self.actions_memory = []
        self.weights = np.ones(self.n_assets) / self.n_assets
        return self._get_state()

    def render(self, mode='human'):
        """
        Вывод информации о среде
        """
        return {
            'min_reward': min(self.rewards_memory),
            'max_reward': max(self.rewards_memory),
            'mean_reward': np.array(self.rewards_memory).mean(),
            'portfolio_value': self.portfolio_value,
            'weights_q0.25': np.quantile(self.weights, 0.25),
            'weights_q0.5': np.quantile(self.weights, 0.5),
            'weights_q0.75': np.quantile(self.weights, 0.75),
            'weights_max': np.max(self.weights),
            'weights_std': self.weights.std()
        }

    def _get_state(self):
        """
        Получение текущего состояния
        """
        values = [stock['data'].iloc[self.current_step].values for stock in self.data]
        observation = np.vstack(values)
        observation = np.concatenate([observation, self.weights[:, None]], axis=1).astype(np.float32)
        observation = np.nan_to_num(observation)
        return observation

    def _get_reward(self, action):
        """
        Вычисление награды
        """

        self.weights += action
        self.weights = softmax_normalization(self.weights)

        self.actions_memory.append(action)

        prices_change_hist = self.close_prices_pct.iloc[self.observations_range[0]:self.current_step + 1]
        current_prices = self.close_prices_pct.iloc[self.current_step].values

        portfolio_value_change = current_prices @ self.weights
        self.portfolio_value += portfolio_value_change

        reward = 0

        if self.objective == 'sharpe':
            mu = rf.mean_vector(prices_change_hist, method='hist')
            cov = rf.covar_matrix(prices_change_hist, method='shrunk')
            reward = rf.Sharpe(self.weights, mu, cov, prices_change_hist, rm=self.risk_measure)
        elif self.objective == 'price_change':
            # reward = portfolio_value_change
            reward = portfolio_value_change
        elif self.objective == 'min_risk':
            mu = rf.mean_vector(prices_change_hist, method='hist')
            cov = rf.covar_matrix(prices_change_hist, method='shrunk')
            reward = -rf.Sharpe_Risk(self.weights, cov, mu, rm=self.risk_measure)

        if np.isinf(reward):
            reward = 0

        self.rewards_memory.append(reward)
        # print('act', self.current_step, np.isnan(action).sum(), np.array(self.rewards_memory).mean())

        return reward

# %%
train_env = PortfolioAllocationEnv(data_file='data/sp500_components_7y.pickle',
                                   sector='Information Technology',
                                   objective='price_change',
                                   drop_close=False,
                                   observations_range=(0, 1260))  # 252 x 5 = 1260, 252 x 3 = 756
check_env(train_env, skip_render_check=False)
# Out:
# /home/hivaze/Documents/CODE-W/PyCharm Projects/portfolio_optimization/venv/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:213: UserWarning: Your observation  has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(

# %% [markdown]
# ### Vectorization of Env

# %%
from stable_baselines3.common.vec_env import VecCheckNan

train_env = DummyVecEnv([lambda: train_env])
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=False)
train_env = VecCheckNan(train_env, raise_exception=True)
# train_env = VecFrameStack(train_env, 15, channels_order='first')

# %%
train_env.observation_space.shape, train_env.action_space.shape
# Out:
# ((63, 14), (63,))

# %% [markdown]
# ## stablebaselines Models

# %%
from stable_baselines3.ppo import MlpPolicy
from sb3_contrib.ppo_recurrent import MlpLstmPolicy
from sb3_contrib import RecurrentPPO

# %%
model = SAC('MlpPolicy', train_env, learning_rate=1e-3,
            verbose=1, tensorboard_log='logs/',
            device='cuda', batch_size=128
            )
model.policy
# Out:
# Using cuda device
# /home/hivaze/Documents/CODE-W/PyCharm Projects/portfolio_optimization/venv/lib/python3.10/site-packages/stable_baselines3/common/buffers.py:229: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 7.32GB > 0.99GB
#   warnings.warn(
# SACPolicy(
#   (actor): Actor(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (latent_pi): Sequential(
#       (0): Linear(in_features=882, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#     )
#     (mu): Linear(in_features=256, out_features=63, bias=True)
#     (log_std): Linear(in_features=256, out_features=63, bias=True)
#   )
#   (critic): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=945, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=945, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (critic_target): ContinuousCritic(
#     (features_extractor): FlattenExtractor(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#     )
#     (qf0): Sequential(
#       (0): Linear(in_features=945, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (qf1): Sequential(
#       (0): Linear(in_features=945, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )

# %%
mean_reward, std_reward = evaluate_policy(model, train_env, n_eval_episodes=1, deterministic=False, warn=False, return_episode_rewards=True)
print(mean_reward, std_reward)
# Out:
# {'min_reward': -0.13507603275974894, 'max_reward': 0.10769509643262032, 'mean_reward': 0.0012846439338780953, 'portfolio_value': 1.618651356686399, 'weights_q0.25': 0.008902000079256317, 'weights_q0.5': 0.015858724883870457, 'weights_q0.75': 0.022327666168714004, 'weights_max': 0.028236541936997102, 'weights_std': 0.007590259833949908}
# [1.6186513373259004] [1260]

# %% [markdown]
# ### Learn loop

# %%
# eval_callback = EvalCallback(eval_env=test_env, best_model_save_path='models/best.stbl',
#                              n_eval_episodes=3, eval_freq=500, render=False, warn=False)
# eval_callback

# %%
class MeanRewardCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(MeanRewardCallback, self).__init__(verbose)
        self.render = {}

    def _on_step(self) -> bool:

        if self.training_env.get_attr('rewards_memory')[0]:  # else - end of episode
            # reward = self.training_env.get_attr('rewards_memory')[0][-1]
            self.render = self.training_env.render()
        else:
            self.logger.record("train/mean_reward", self.render['mean_reward'])
            self.logger.record("train/min_reward", self.render['min_reward'])
            self.logger.record("train/max_reward", self.render['max_reward'])
            self.logger.record("train/portfolio_value", self.render['portfolio_value'])

        return True

# %%
model_name = 'SAC-mr-it-256-256-64-dw'
model.learn(total_timesteps=120_000, progress_bar=False, log_interval=1,
            reset_num_timesteps=False, tb_log_name=model_name,
            callback=MeanRewardCallback())
# Out:
# Logging to logs/SAC-mr-it-256-256-64-dw_0
# {'min_reward': -0.13762619245864277, 'max_reward': 0.11277066807282608, 'mean_reward': 0.001214601025250331, 'portfolio_value': 1.530397291815418, 'weights_q0.25': 0.008926459422853462, 'weights_q0.5': 0.014768917028864586, 'weights_q0.75': 0.022431659233683038, 'weights_max': 0.03455021941076303, 'weights_std': 0.008203804591619736}
# ---------------------------------
# | time/              |          |
# |    episodes        | 1        |
# |    fps             | 123      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1260     |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 1.27     |
# |    ent_coef        | 0.316    |
# |    ent_coef_loss   | -120     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.113    |
# |    mean_reward     | 0.00121  |
# |    min_reward      | -0.138   |
# |    n_updates       | 1158     |
# |    portfolio_value | 1.52     |
# ---------------------------------
# {'min_reward': -0.13631164096142673, 'max_reward': 0.11323034863140241, 'mean_reward': 0.0012083249375208793, 'portfolio_value': 1.5224894212763058, 'weights_q0.25': 0.007388540881843037, 'weights_q0.5': 0.009828067177397468, 'weights_q0.75': 0.026488335002353005, 'weights_max': 0.03451327440537026, 'weights_std': 0.010269942281193876}
# ---------------------------------
# | time/              |          |
# |    episodes        | 2        |
# |    fps             | 125      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2520     |
# | train/             |          |
# |    actor_loss      | -120     |
# |    critic_loss     | 1.45     |
# |    ent_coef        | 0.0924   |
# |    ent_coef_loss   | -233     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.113    |
# |    mean_reward     | 0.0012   |
# |    min_reward      | -0.136   |
# |    n_updates       | 2418     |
# |    portfolio_value | 1.51     |
# ---------------------------------
# {'min_reward': -0.13667083760121135, 'max_reward': 0.11519786102225502, 'mean_reward': 0.00121188307381893, 'portfolio_value': 1.5269726730118507, 'weights_q0.25': 0.007226567843121549, 'weights_q0.5': 0.012996847362249979, 'weights_q0.75': 0.025277207198117164, 'weights_max': 0.03397985220779822, 'weights_std': 0.009612307259436303}
# ---------------------------------
# | time/              |          |
# |    episodes        | 3        |
# |    fps             | 125      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 3780     |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 0.652    |
# |    ent_coef        | 0.0277   |
# |    ent_coef_loss   | -313     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.115    |
# |    mean_reward     | 0.00121  |
# |    min_reward      | -0.137   |
# |    n_updates       | 3678     |
# |    portfolio_value | 1.52     |
# ---------------------------------
# {'min_reward': -0.13750656238889858, 'max_reward': 0.11058237951763797, 'mean_reward': 0.0012258019837983276, 'portfolio_value': 1.544510499585892, 'weights_q0.25': 0.005654897524407878, 'weights_q0.5': 0.011609663270963164, 'weights_q0.75': 0.02854675291917201, 'weights_max': 0.03417568068942708, 'weights_std': 0.010855338827222269}
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 124      |
# |    time_elapsed    | 35       |
# |    total_timesteps | 5040     |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 0.693    |
# |    ent_coef        | 0.00915  |
# |    ent_coef_loss   | -299     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.111    |
# |    mean_reward     | 0.00122  |
# |    min_reward      | -0.138   |
# |    n_updates       | 4938     |
# |    portfolio_value | 1.54     |
# ---------------------------------
# {'min_reward': -0.13902670727044575, 'max_reward': 0.1115604325341022, 'mean_reward': 0.0011782392308743778, 'portfolio_value': 1.4845814309017156, 'weights_q0.25': 0.0049150238753816865, 'weights_q0.5': 0.012734027648197074, 'weights_q0.75': 0.026133723024581036, 'weights_max': 0.033768346942701734, 'weights_std': 0.01103672390312642}
# ---------------------------------
# | time/              |          |
# |    episodes        | 5        |
# |    fps             | 124      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 6300     |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 0.334    |
# |    ent_coef        | 0.00368  |
# |    ent_coef_loss   | -266     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.112    |
# |    mean_reward     | 0.00117  |
# |    min_reward      | -0.139   |
# |    n_updates       | 6198     |
# |    portfolio_value | 1.48     |
# ---------------------------------
# {'min_reward': -0.14518002223484763, 'max_reward': 0.11915938741806945, 'mean_reward': 0.001140793991865973, 'portfolio_value': 1.4374004297511254, 'weights_q0.25': 0.004305594393426312, 'weights_q0.5': 0.01797176601364251, 'weights_q0.75': 0.027167595560516587, 'weights_max': 0.029641599782210797, 'weights_std': 0.010635918542051054}
# ---------------------------------
# | time/              |          |
# |    episodes        | 6        |
# |    fps             | 123      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 7560     |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 0.361    |
# |    ent_coef        | 0.00184  |
# |    ent_coef_loss   | -115     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.119    |
# |    mean_reward     | 0.00113  |
# |    min_reward      | -0.145   |
# |    n_updates       | 7458     |
# |    portfolio_value | 1.43     |
# ---------------------------------
# {'min_reward': -0.13260092237589238, 'max_reward': 0.10933212922227598, 'mean_reward': 0.0012327969611862922, 'portfolio_value': 1.5533241710947299, 'weights_q0.25': 0.004064556984000499, 'weights_q0.5': 0.014712634291816368, 'weights_q0.75': 0.02733555888229173, 'weights_max': 0.028537744194785695, 'weights_std': 0.010817145375557448}
# ---------------------------------
# | time/              |          |
# |    episodes        | 7        |
# |    fps             | 123      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 8820     |
# | train/             |          |
# |    actor_loss      | -97.7    |
# |    critic_loss     | 0.336    |
# |    ent_coef        | 0.00123  |
# |    ent_coef_loss   | 25.1     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.109    |
# |    mean_reward     | 0.00123  |
# |    min_reward      | -0.133   |
# |    n_updates       | 8718     |
# |    portfolio_value | 1.54     |
# ---------------------------------
# {'min_reward': -0.14008464224573192, 'max_reward': 0.11297253268293958, 'mean_reward': 0.0012977977601832114, 'portfolio_value': 1.6352251778308458, 'weights_q0.25': 0.004832103319609595, 'weights_q0.5': 0.016541764793607895, 'weights_q0.75': 0.027490216895842516, 'weights_max': 0.02901848515238355, 'weights_std': 0.010305338501958316}
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 123      |
# |    time_elapsed    | 76       |
# |    total_timesteps | 10080    |
# | train/             |          |
# |    actor_loss      | -97.7    |
# |    critic_loss     | 0.135    |
# |    ent_coef        | 0.00091  |
# |    ent_coef_loss   | -57.7    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.113    |
# |    mean_reward     | 0.00129  |
# |    min_reward      | -0.14    |
# |    n_updates       | 9978     |
# |    portfolio_value | 1.62     |
# ---------------------------------
# {'min_reward': -0.13650911511289443, 'max_reward': 0.10670454921741707, 'mean_reward': 0.0012514455554525768, 'portfolio_value': 1.5768213998702463, 'weights_q0.25': 0.006094118330749366, 'weights_q0.5': 0.01578794158193488, 'weights_q0.75': 0.025303311175753206, 'weights_max': 0.03083220660162444, 'weights_std': 0.00936504909320764}
# ---------------------------------
# | time/              |          |
# |    episodes        | 9        |
# |    fps             | 123      |
# |    time_elapsed    | 87       |
# |    total_timesteps | 11340    |
# | train/             |          |
# |    actor_loss      | -88.2    |
# |    critic_loss     | 0.233    |
# |    ent_coef        | 0.000799 |
# |    ent_coef_loss   | 44       |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.107    |
# |    mean_reward     | 0.00124  |
# |    min_reward      | -0.137   |
# |    n_updates       | 11238    |
# |    portfolio_value | 1.57     |
# ---------------------------------
# {'min_reward': -0.13714426587608225, 'max_reward': 0.10262322503505358, 'mean_reward': 0.0011079583976048358, 'portfolio_value': 1.3960275809820926, 'weights_q0.25': 0.004590212782470128, 'weights_q0.5': 0.01304291652593929, 'weights_q0.75': 0.028125066819764264, 'weights_max': 0.03046732995596939, 'weights_std': 0.011087588191003242}
# ---------------------------------
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 122      |
# |    time_elapsed    | 97       |
# |    total_timesteps | 12600    |
# | train/             |          |
# |    actor_loss      | -84      |
# |    critic_loss     | 0.197    |
# |    ent_coef        | 0.000805 |
# |    ent_coef_loss   | 133      |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.103    |
# |    mean_reward     | 0.0011   |
# |    min_reward      | -0.137   |
# |    n_updates       | 12498    |
# |    portfolio_value | 1.38     |
# ---------------------------------
# {'min_reward': -0.12792767714062733, 'max_reward': 0.10231852431445698, 'mean_reward': 0.0012507786600172847, 'portfolio_value': 1.5759811116217808, 'weights_q0.25': 0.007441272210515026, 'weights_q0.5': 0.011478789539847562, 'weights_q0.75': 0.02536970231597281, 'weights_max': 0.035644957213901575, 'weights_std': 0.009795384225154528}
# ---------------------------------
# | time/              |          |
# |    episodes        | 11       |
# |    fps             | 121      |
# |    time_elapsed    | 108      |
# |    total_timesteps | 13860    |
# | train/             |          |
# |    actor_loss      | -79.1    |
# |    critic_loss     | 0.0761   |
# |    ent_coef        | 0.000609 |
# |    ent_coef_loss   | 20.8     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.102    |
# |    mean_reward     | 0.00124  |
# |    min_reward      | -0.128   |
# |    n_updates       | 13758    |
# |    portfolio_value | 1.57     |
# ---------------------------------
# {'min_reward': -0.14122716222625173, 'max_reward': 0.11358606675090242, 'mean_reward': 0.0011578993056955273, 'portfolio_value': 1.4589531251763643, 'weights_q0.25': 0.005162924543692947, 'weights_q0.5': 0.011899011424705501, 'weights_q0.75': 0.027811384776643237, 'weights_max': 0.03151749013022929, 'weights_std': 0.01078829043038073}
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 121      |
# |    time_elapsed    | 119      |
# |    total_timesteps | 15120    |
# | train/             |          |
# |    actor_loss      | -73.5    |
# |    critic_loss     | 0.124    |
# |    ent_coef        | 0.000505 |
# |    ent_coef_loss   | -83.1    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.114    |
# |    mean_reward     | 0.00115  |
# |    min_reward      | -0.141   |
# |    n_updates       | 15018    |
# |    portfolio_value | 1.45     |
# ---------------------------------
# {'min_reward': -0.1323552978242737, 'max_reward': 0.1095371931923064, 'mean_reward': 0.001208752317490461, 'portfolio_value': 1.523027920037978, 'weights_q0.25': 0.008256943127009888, 'weights_q0.5': 0.01315550257487445, 'weights_q0.75': 0.0228904919064804, 'weights_max': 0.03231104546443533, 'weights_std': 0.00889317683418629}
# ---------------------------------
# | time/              |          |
# |    episodes        | 13       |
# |    fps             | 121      |
# |    time_elapsed    | 130      |
# |    total_timesteps | 16380    |
# | train/             |          |
# |    actor_loss      | -68.2    |
# |    critic_loss     | 0.0688   |
# |    ent_coef        | 0.000435 |
# |    ent_coef_loss   | 138      |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.11     |
# |    mean_reward     | 0.0012   |
# |    min_reward      | -0.132   |
# |    n_updates       | 16278    |
# |    portfolio_value | 1.51     |
# ---------------------------------
# {'min_reward': -0.13062243956858993, 'max_reward': 0.11421802128529124, 'mean_reward': 0.0011701368623129866, 'portfolio_value': 1.4743724465143624, 'weights_q0.25': 0.009786732655293992, 'weights_q0.5': 0.014196382069506751, 'weights_q0.75': 0.01995548049118694, 'weights_max': 0.03947591955265054, 'weights_std': 0.007808710183985403}
# ---------------------------------
# | time/              |          |
# |    episodes        | 14       |
# |    fps             | 121      |
# |    time_elapsed    | 140      |
# |    total_timesteps | 17640    |
# | train/             |          |
# |    actor_loss      | -63      |
# |    critic_loss     | 0.0254   |
# |    ent_coef        | 0.000495 |
# |    ent_coef_loss   | -249     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.114    |
# |    mean_reward     | 0.00116  |
# |    min_reward      | -0.131   |
# |    n_updates       | 17538    |
# |    portfolio_value | 1.46     |
# ---------------------------------
# {'min_reward': -0.13402097887573333, 'max_reward': 0.11811546297035333, 'mean_reward': 0.0012417371839525994, 'portfolio_value': 1.5645888517802728, 'weights_q0.25': 0.01045364969612185, 'weights_q0.5': 0.01328423313239496, 'weights_q0.75': 0.020038130919565328, 'weights_max': 0.03458208459635122, 'weights_std': 0.007800428456007967}
# ---------------------------------
# | time/              |          |
# |    episodes        | 15       |
# |    fps             | 120      |
# |    time_elapsed    | 151      |
# |    total_timesteps | 18900    |
# | train/             |          |
# |    actor_loss      | -57.1    |
# |    critic_loss     | 0.0337   |
# |    ent_coef        | 0.00034  |
# |    ent_coef_loss   | -67.4    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.118    |
# |    mean_reward     | 0.00123  |
# |    min_reward      | -0.134   |
# |    n_updates       | 18798    |
# |    portfolio_value | 1.55     |
# ---------------------------------
# {'min_reward': -0.132104122175971, 'max_reward': 0.09832692793514658, 'mean_reward': 0.0011514796371353629, 'portfolio_value': 1.4508643427905585, 'weights_q0.25': 0.010282036048796154, 'weights_q0.5': 0.015498819069898931, 'weights_q0.75': 0.019248009574780553, 'weights_max': 0.03464045040548741, 'weights_std': 0.00721811865220718}
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 120      |
# |    time_elapsed    | 162      |
# |    total_timesteps | 20160    |
# | train/             |          |
# |    actor_loss      | -56.4    |
# |    critic_loss     | 0.0328   |
# |    ent_coef        | 0.000361 |
# |    ent_coef_loss   | -53.3    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.0983   |
# |    mean_reward     | 0.00115  |
# |    min_reward      | -0.132   |
# |    n_updates       | 20058    |
# |    portfolio_value | 1.44     |
# ---------------------------------
# {'min_reward': -0.13683665072389795, 'max_reward': 0.10368446619700444, 'mean_reward': 0.0012425567043368943, 'portfolio_value': 1.5656214474644876, 'weights_q0.25': 0.010178451861613192, 'weights_q0.5': 0.014252268258277368, 'weights_q0.75': 0.021420445256281857, 'weights_max': 0.03118438698711908, 'weights_std': 0.00696809148471965}
# ---------------------------------
# | time/              |          |
# |    episodes        | 17       |
# |    fps             | 120      |
# |    time_elapsed    | 173      |
# |    total_timesteps | 21420    |
# | train/             |          |
# |    actor_loss      | -48.6    |
# |    critic_loss     | 0.0444   |
# |    ent_coef        | 0.000251 |
# |    ent_coef_loss   | -138     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.104    |
# |    mean_reward     | 0.00124  |
# |    min_reward      | -0.137   |
# |    n_updates       | 21318    |
# |    portfolio_value | 1.56     |
# ---------------------------------
# {'min_reward': -0.13424547958452918, 'max_reward': 0.11951997382093418, 'mean_reward': 0.0012392403861336498, 'portfolio_value': 1.5614428865283982, 'weights_q0.25': 0.00844547296460033, 'weights_q0.5': 0.012990447803922164, 'weights_q0.75': 0.022054735340621714, 'weights_max': 0.036350881166743995, 'weights_std': 0.008440117821982434}
# ---------------------------------
# | time/              |          |
# |    episodes        | 18       |
# |    fps             | 119      |
# |    time_elapsed    | 184      |
# |    total_timesteps | 22680    |
# | train/             |          |
# |    actor_loss      | -46.6    |
# |    critic_loss     | 0.0291   |
# |    ent_coef        | 0.000252 |
# |    ent_coef_loss   | 37.5     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.12     |
# |    mean_reward     | 0.00123  |
# |    min_reward      | -0.134   |
# |    n_updates       | 22578    |
# |    portfolio_value | 1.55     |
# ---------------------------------
# {'min_reward': -0.1354245132966394, 'max_reward': 0.11130601364304249, 'mean_reward': 0.0011414752042163533, 'portfolio_value': 1.4382587573126058, 'weights_q0.25': 0.008592182918727473, 'weights_q0.5': 0.014885529048273467, 'weights_q0.75': 0.02207111536003401, 'weights_max': 0.03202323322220384, 'weights_std': 0.007788287866070379}
# ---------------------------------
# | time/              |          |
# |    episodes        | 19       |
# |    fps             | 119      |
# |    time_elapsed    | 194      |
# |    total_timesteps | 23940    |
# | train/             |          |
# |    actor_loss      | -45.8    |
# |    critic_loss     | 0.0359   |
# |    ent_coef        | 0.000206 |
# |    ent_coef_loss   | 135      |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.111    |
# |    mean_reward     | 0.00113  |
# |    min_reward      | -0.135   |
# |    n_updates       | 23838    |
# |    portfolio_value | 1.43     |
# ---------------------------------
# {'min_reward': -0.13389824174192766, 'max_reward': 0.1118529924054516, 'mean_reward': 0.0011731463054341308, 'portfolio_value': 1.4781643448470045, 'weights_q0.25': 0.010981333715396339, 'weights_q0.5': 0.014502310332436437, 'weights_q0.75': 0.01905706939982802, 'weights_max': 0.03628176651658472, 'weights_std': 0.006833698387672778}
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 119      |
# |    time_elapsed    | 205      |
# |    total_timesteps | 25200    |
# | train/             |          |
# |    actor_loss      | -43.4    |
# |    critic_loss     | 0.00565  |
# |    ent_coef        | 0.000188 |
# |    ent_coef_loss   | -157     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.112    |
# |    mean_reward     | 0.00117  |
# |    min_reward      | -0.134   |
# |    n_updates       | 25098    |
# |    portfolio_value | 1.47     |
# ---------------------------------
# {'min_reward': -0.1301912444450698, 'max_reward': 0.10879027672533903, 'mean_reward': 0.0011387359552285398, 'portfolio_value': 1.4348073035879594, 'weights_q0.25': 0.009219998052941849, 'weights_q0.5': 0.01527419272806759, 'weights_q0.75': 0.020578858600525315, 'weights_max': 0.032699901038049, 'weights_std': 0.007546964809605779}
# ---------------------------------
# | time/              |          |
# |    episodes        | 21       |
# |    fps             | 116      |
# |    time_elapsed    | 221      |
# |    total_timesteps | 26460    |
# | train/             |          |
# |    actor_loss      | -39.1    |
# |    critic_loss     | 0.0122   |
# |    ent_coef        | 0.000195 |
# |    ent_coef_loss   | -125     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.109    |
# |    mean_reward     | 0.00113  |
# |    min_reward      | -0.13    |
# |    n_updates       | 26358    |
# |    portfolio_value | 1.42     |
# ---------------------------------
# {'min_reward': -0.13667954139786342, 'max_reward': 0.1017866750395333, 'mean_reward': 0.0011973194472257908, 'portfolio_value': 1.5086225035044978, 'weights_q0.25': 0.008700299565180555, 'weights_q0.5': 0.013623302239350654, 'weights_q0.75': 0.022349626253012442, 'weights_max': 0.034986481324119974, 'weights_std': 0.008003723871289033}
# ---------------------------------
# | time/              |          |
# |    episodes        | 22       |
# |    fps             | 116      |
# |    time_elapsed    | 231      |
# |    total_timesteps | 27720    |
# | train/             |          |
# |    actor_loss      | -33.2    |
# |    critic_loss     | 0.00926  |
# |    ent_coef        | 0.000162 |
# |    ent_coef_loss   | -168     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.102    |
# |    mean_reward     | 0.00119  |
# |    min_reward      | -0.137   |
# |    n_updates       | 27618    |
# |    portfolio_value | 1.5      |
# ---------------------------------
# {'min_reward': -0.13642937856172854, 'max_reward': 0.1067497995186381, 'mean_reward': 0.0011855530586256005, 'portfolio_value': 1.4937968538682571, 'weights_q0.25': 0.008970489474621424, 'weights_q0.5': 0.013579458861240186, 'weights_q0.75': 0.020910403574129457, 'weights_max': 0.03564914859374192, 'weights_std': 0.007921278971378109}
# ---------------------------------
# | time/              |          |
# |    episodes        | 23       |
# |    fps             | 117      |
# |    time_elapsed    | 241      |
# |    total_timesteps | 28980    |
# | train/             |          |
# |    actor_loss      | -35.8    |
# |    critic_loss     | 0.0192   |
# |    ent_coef        | 0.000118 |
# |    ent_coef_loss   | -34.2    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.107    |
# |    mean_reward     | 0.00118  |
# |    min_reward      | -0.136   |
# |    n_updates       | 28878    |
# |    portfolio_value | 1.48     |
# ---------------------------------
# {'min_reward': -0.13124341968778075, 'max_reward': 0.10656800938323842, 'mean_reward': 0.0011786776320102483, 'portfolio_value': 1.485133816332912, 'weights_q0.25': 0.00829442356855419, 'weights_q0.5': 0.014432491631693842, 'weights_q0.75': 0.021775036113699082, 'weights_max': 0.03394366746812173, 'weights_std': 0.008023635031552335}
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 117      |
# |    time_elapsed    | 252      |
# |    total_timesteps | 30240    |
# | train/             |          |
# |    actor_loss      | -32.8    |
# |    critic_loss     | 0.00939  |
# |    ent_coef        | 0.000176 |
# |    ent_coef_loss   | -300     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.107    |
# |    mean_reward     | 0.00117  |
# |    min_reward      | -0.131   |
# |    n_updates       | 30138    |
# |    portfolio_value | 1.47     |
# ---------------------------------
# {'min_reward': -0.12937001973036844, 'max_reward': 0.10192825185047509, 'mean_reward': 0.0012675820972008435, 'portfolio_value': 1.597153442473065, 'weights_q0.25': 0.008916002784828393, 'weights_q0.5': 0.014742496824839791, 'weights_q0.75': 0.02246471620507693, 'weights_max': 0.0312361248629495, 'weights_std': 0.007949658954151853}
# ---------------------------------
# | time/              |          |
# |    episodes        | 25       |
# |    fps             | 117      |
# |    time_elapsed    | 263      |
# |    total_timesteps | 31500    |
# | train/             |          |
# |    actor_loss      | -28.5    |
# |    critic_loss     | 0.00813  |
# |    ent_coef        | 0.000137 |
# |    ent_coef_loss   | -46.9    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.102    |
# |    mean_reward     | 0.00126  |
# |    min_reward      | -0.129   |
# |    n_updates       | 31398    |
# |    portfolio_value | 1.59     |
# ---------------------------------
# {'min_reward': -0.13082195810424022, 'max_reward': 0.10360440555763799, 'mean_reward': 0.0012629638605469611, 'portfolio_value': 1.5913344642891725, 'weights_q0.25': 0.008151958772852198, 'weights_q0.5': 0.014114154250400265, 'weights_q0.75': 0.023881702869696958, 'weights_max': 0.03212754522672605, 'weights_std': 0.00819096798843097}
# ---------------------------------
# | time/              |          |
# |    episodes        | 26       |
# |    fps             | 117      |
# |    time_elapsed    | 274      |
# |    total_timesteps | 32760    |
# | train/             |          |
# |    actor_loss      | -28.7    |
# |    critic_loss     | 0.00707  |
# |    ent_coef        | 0.0001   |
# |    ent_coef_loss   | -28.5    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.104    |
# |    mean_reward     | 0.00125  |
# |    min_reward      | -0.131   |
# |    n_updates       | 32658    |
# |    portfolio_value | 1.58     |
# ---------------------------------
# {'min_reward': -0.13438252095926573, 'max_reward': 0.1094702285306408, 'mean_reward': 0.001249175852488801, 'portfolio_value': 1.5739615741358886, 'weights_q0.25': 0.008288932606796893, 'weights_q0.5': 0.012668956413070224, 'weights_q0.75': 0.02401919603944998, 'weights_max': 0.03242321905237466, 'weights_std': 0.008948614892907747}
# ---------------------------------
# | time/              |          |
# |    episodes        | 27       |
# |    fps             | 117      |
# |    time_elapsed    | 284      |
# |    total_timesteps | 34020    |
# | train/             |          |
# |    actor_loss      | -24.9    |
# |    critic_loss     | 0.00427  |
# |    ent_coef        | 8.81e-05 |
# |    ent_coef_loss   | -219     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.109    |
# |    mean_reward     | 0.00124  |
# |    min_reward      | -0.134   |
# |    n_updates       | 33918    |
# |    portfolio_value | 1.56     |
# ---------------------------------
# {'min_reward': -0.13314003598536928, 'max_reward': 0.10407667646817076, 'mean_reward': 0.0012324031556826384, 'portfolio_value': 1.5528279761601251, 'weights_q0.25': 0.00737031216535008, 'weights_q0.5': 0.014455734394826602, 'weights_q0.75': 0.02202087993829458, 'weights_max': 0.032194336291797805, 'weights_std': 0.008577050483837247}
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 117      |
# |    time_elapsed    | 295      |
# |    total_timesteps | 35280    |
# | train/             |          |
# |    actor_loss      | -24.4    |
# |    critic_loss     | 0.0127   |
# |    ent_coef        | 8.62e-05 |
# |    ent_coef_loss   | 353      |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.104    |
# |    mean_reward     | 0.00122  |
# |    min_reward      | -0.133   |
# |    n_updates       | 35178    |
# |    portfolio_value | 1.54     |
# ---------------------------------
# {'min_reward': -0.12942116162020204, 'max_reward': 0.10459835422470323, 'mean_reward': 0.001224895258692455, 'portfolio_value': 1.5433680259524936, 'weights_q0.25': 0.008504259151991137, 'weights_q0.5': 0.015212254761135979, 'weights_q0.75': 0.021159504477829848, 'weights_max': 0.03251701135298192, 'weights_std': 0.008082991517075021}
# ---------------------------------
# | time/              |          |
# |    episodes        | 29       |
# |    fps             | 117      |
# |    time_elapsed    | 305      |
# |    total_timesteps | 36540    |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 0.0151   |
# |    ent_coef        | 8.64e-05 |
# |    ent_coef_loss   | -137     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.105    |
# |    mean_reward     | 0.00122  |
# |    min_reward      | -0.129   |
# |    n_updates       | 36438    |
# |    portfolio_value | 1.53     |
# ---------------------------------
# {'min_reward': -0.12948750345897983, 'max_reward': 0.10720852742994127, 'mean_reward': 0.0011719347181104723, 'portfolio_value': 1.476637744819196, 'weights_q0.25': 0.007899845318121651, 'weights_q0.5': 0.015002276068616741, 'weights_q0.75': 0.021195377422139037, 'weights_max': 0.03359570664706618, 'weights_std': 0.008385191639899862}
# ---------------------------------
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 116      |
# |    time_elapsed    | 318      |
# |    total_timesteps | 37800    |
# | train/             |          |
# |    actor_loss      | -21.8    |
# |    critic_loss     | 0.00588  |
# |    ent_coef        | 6.82e-05 |
# |    ent_coef_loss   | -164     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.107    |
# |    mean_reward     | 0.00116  |
# |    min_reward      | -0.129   |
# |    n_updates       | 37698    |
# |    portfolio_value | 1.46     |
# ---------------------------------
# {'min_reward': -0.13567125849961706, 'max_reward': 0.1060540443753064, 'mean_reward': 0.0012152338169907715, 'portfolio_value': 1.531194609408373, 'weights_q0.25': 0.007497569416007435, 'weights_q0.5': 0.013419067183473765, 'weights_q0.75': 0.02256180227173923, 'weights_max': 0.03734674582495306, 'weights_std': 0.009290789265064771}
# ---------------------------------
# | time/              |          |
# |    episodes        | 31       |
# |    fps             | 116      |
# |    time_elapsed    | 329      |
# |    total_timesteps | 39060    |
# | train/             |          |
# |    actor_loss      | -20.6    |
# |    critic_loss     | 0.00215  |
# |    ent_coef        | 7.07e-05 |
# |    ent_coef_loss   | -99.5    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.106    |
# |    mean_reward     | 0.00121  |
# |    min_reward      | -0.136   |
# |    n_updates       | 38958    |
# |    portfolio_value | 1.52     |
# ---------------------------------
# {'min_reward': -0.14000077260558508, 'max_reward': 0.11081975053660502, 'mean_reward': 0.0012098769151682115, 'portfolio_value': 1.524444913111948, 'weights_q0.25': 0.009390858534822126, 'weights_q0.5': 0.014281402509619553, 'weights_q0.75': 0.0220902497981707, 'weights_max': 0.03555095157702119, 'weights_std': 0.007987321401986422}
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 116      |
# |    time_elapsed    | 339      |
# |    total_timesteps | 40320    |
# | train/             |          |
# |    actor_loss      | -18.6    |
# |    critic_loss     | 0.00328  |
# |    ent_coef        | 8.22e-05 |
# |    ent_coef_loss   | -152     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.111    |
# |    mean_reward     | 0.0012   |
# |    min_reward      | -0.14    |
# |    n_updates       | 40218    |
# |    portfolio_value | 1.51     |
# ---------------------------------
# {'min_reward': -0.13494741036311972, 'max_reward': 0.10886082373310345, 'mean_reward': 0.0011939016435584047, 'portfolio_value': 1.5043160708835914, 'weights_q0.25': 0.008166547323382178, 'weights_q0.5': 0.013611955518922364, 'weights_q0.75': 0.021813128198715136, 'weights_max': 0.03537411678253428, 'weights_std': 0.008607337141304603}
# ---------------------------------
# | time/              |          |
# |    episodes        | 33       |
# |    fps             | 117      |
# |    time_elapsed    | 350      |
# |    total_timesteps | 41580    |
# | train/             |          |
# |    actor_loss      | -16.9    |
# |    critic_loss     | 0.00318  |
# |    ent_coef        | 9.75e-05 |
# |    ent_coef_loss   | 95       |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.109    |
# |    mean_reward     | 0.00118  |
# |    min_reward      | -0.135   |
# |    n_updates       | 41478    |
# |    portfolio_value | 1.49     |
# ---------------------------------
# {'min_reward': -0.13915733658779814, 'max_reward': 0.10580870469362885, 'mean_reward': 0.0011454882444978083, 'portfolio_value': 1.4433151880672386, 'weights_q0.25': 0.007609626626074537, 'weights_q0.5': 0.014287223153335256, 'weights_q0.75': 0.022682979625287224, 'weights_max': 0.03625661219863853, 'weights_std': 0.009047839643422494}
# ---------------------------------
# | time/              |          |
# |    episodes        | 34       |
# |    fps             | 117      |
# |    time_elapsed    | 360      |
# |    total_timesteps | 42840    |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.00875  |
# |    ent_coef        | 8.01e-05 |
# |    ent_coef_loss   | -154     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.106    |
# |    mean_reward     | 0.00114  |
# |    min_reward      | -0.139   |
# |    n_updates       | 42738    |
# |    portfolio_value | 1.43     |
# ---------------------------------
# {'min_reward': -0.1337742413818367, 'max_reward': 0.1167522397429174, 'mean_reward': 0.001231180178445439, 'portfolio_value': 1.5512870248412531, 'weights_q0.25': 0.007855718218322847, 'weights_q0.5': 0.012754512040001179, 'weights_q0.75': 0.024847951835366533, 'weights_max': 0.0337566354336927, 'weights_std': 0.009087311678361085}
# ---------------------------------
# | time/              |          |
# |    episodes        | 35       |
# |    fps             | 117      |
# |    time_elapsed    | 370      |
# |    total_timesteps | 44100    |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.00169  |
# |    ent_coef        | 5.95e-05 |
# |    ent_coef_loss   | 42.4     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.117    |
# |    mean_reward     | 0.00122  |
# |    min_reward      | -0.134   |
# |    n_updates       | 43998    |
# |    portfolio_value | 1.54     |
# ---------------------------------
# {'min_reward': -0.1378237315025368, 'max_reward': 0.1069083339065035, 'mean_reward': 0.001292047921772122, 'portfolio_value': 1.6279803814328722, 'weights_q0.25': 0.007455293157222909, 'weights_q0.5': 0.013555387039881992, 'weights_q0.75': 0.022556095919608873, 'weights_max': 0.03649970106681037, 'weights_std': 0.008742233617799198}
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 117      |
# |    time_elapsed    | 380      |
# |    total_timesteps | 45360    |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 0.00469  |
# |    ent_coef        | 4.88e-05 |
# |    ent_coef_loss   | -16.3    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.107    |
# |    mean_reward     | 0.00128  |
# |    min_reward      | -0.138   |
# |    n_updates       | 45258    |
# |    portfolio_value | 1.62     |
# ---------------------------------
# {'min_reward': -0.13906733211149003, 'max_reward': 0.11489154382186478, 'mean_reward': 0.0012184767781201883, 'portfolio_value': 1.5352807404314361, 'weights_q0.25': 0.00824199801525003, 'weights_q0.5': 0.010810971345587653, 'weights_q0.75': 0.02338557186795157, 'weights_max': 0.038382415317215805, 'weights_std': 0.009762833353784242}
# ---------------------------------
# | time/              |          |
# |    episodes        | 37       |
# |    fps             | 117      |
# |    time_elapsed    | 391      |
# |    total_timesteps | 46620    |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 0.000705 |
# |    ent_coef        | 4.2e-05  |
# |    ent_coef_loss   | -68.7    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.115    |
# |    mean_reward     | 0.00121  |
# |    min_reward      | -0.139   |
# |    n_updates       | 46518    |
# |    portfolio_value | 1.52     |
# ---------------------------------
# {'min_reward': -0.1332880482906423, 'max_reward': 0.10476833928009056, 'mean_reward': 0.0012518577410735156, 'portfolio_value': 1.57734075375263, 'weights_q0.25': 0.006999582408740877, 'weights_q0.5': 0.012286980148940769, 'weights_q0.75': 0.025180389592906603, 'weights_max': 0.03737054398513031, 'weights_std': 0.010071051871451835}
# ---------------------------------
# | time/              |          |
# |    episodes        | 38       |
# |    fps             | 117      |
# |    time_elapsed    | 401      |
# |    total_timesteps | 47880    |
# | train/             |          |
# |    actor_loss      | -11.2    |
# |    critic_loss     | 0.00167  |
# |    ent_coef        | 4.27e-05 |
# |    ent_coef_loss   | -53.6    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.105    |
# |    mean_reward     | 0.00124  |
# |    min_reward      | -0.133   |
# |    n_updates       | 47778    |
# |    portfolio_value | 1.57     |
# ---------------------------------
# {'min_reward': -0.13867606464076973, 'max_reward': 0.11283571328910215, 'mean_reward': 0.0012388652018633383, 'portfolio_value': 1.5609701543478083, 'weights_q0.25': 0.007333488616851354, 'weights_q0.5': 0.01312895507679782, 'weights_q0.75': 0.02459413864725391, 'weights_max': 0.03583953256193604, 'weights_std': 0.009507446612083739}
# ---------------------------------
# | time/              |          |
# |    episodes        | 39       |
# |    fps             | 117      |
# |    time_elapsed    | 412      |
# |    total_timesteps | 49140    |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.000676 |
# |    ent_coef        | 4.74e-05 |
# |    ent_coef_loss   | -380     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.113    |
# |    mean_reward     | 0.00123  |
# |    min_reward      | -0.139   |
# |    n_updates       | 49038    |
# |    portfolio_value | 1.55     |
# ---------------------------------
# {'min_reward': -0.13500610444332578, 'max_reward': 0.11417721217121694, 'mean_reward': 0.0012958024456395645, 'portfolio_value': 1.6327110815058519, 'weights_q0.25': 0.008722821925839192, 'weights_q0.5': 0.013546539950457107, 'weights_q0.75': 0.021436673188727356, 'weights_max': 0.0355683862754832, 'weights_std': 0.008690444462224417}
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 117      |
# |    time_elapsed    | 422      |
# |    total_timesteps | 50400    |
# | train/             |          |
# |    actor_loss      | -9.93    |
# |    critic_loss     | 0.000717 |
# |    ent_coef        | 3.84e-05 |
# |    ent_coef_loss   | 50.3     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.114    |
# |    mean_reward     | 0.00129  |
# |    min_reward      | -0.135   |
# |    n_updates       | 50298    |
# |    portfolio_value | 1.62     |
# ---------------------------------
# {'min_reward': -0.13338159095852017, 'max_reward': 0.1118263532156103, 'mean_reward': 0.0012756261767466236, 'portfolio_value': 1.6072889827007444, 'weights_q0.25': 0.008635755490166461, 'weights_q0.5': 0.012053056310180813, 'weights_q0.75': 0.023244647150670126, 'weights_max': 0.0334613183349261, 'weights_std': 0.008849481026027336}
# ---------------------------------
# | time/              |          |
# |    episodes        | 41       |
# |    fps             | 117      |
# |    time_elapsed    | 433      |
# |    total_timesteps | 51660    |
# | train/             |          |
# |    actor_loss      | -10.3    |
# |    critic_loss     | 0.0021   |
# |    ent_coef        | 2.31e-05 |
# |    ent_coef_loss   | -152     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.112    |
# |    mean_reward     | 0.00127  |
# |    min_reward      | -0.133   |
# |    n_updates       | 51558    |
# |    portfolio_value | 1.6      |
# ---------------------------------
# {'min_reward': -0.1357458296099616, 'max_reward': 0.11285047922871638, 'mean_reward': 0.0012174845112558376, 'portfolio_value': 1.5340304841823558, 'weights_q0.25': 0.007945699385821138, 'weights_q0.5': 0.012387790554267803, 'weights_q0.75': 0.022148749281666744, 'weights_max': 0.03481594448779369, 'weights_std': 0.009349645523361273}
# ---------------------------------
# | time/              |          |
# |    episodes        | 42       |
# |    fps             | 117      |
# |    time_elapsed    | 443      |
# |    total_timesteps | 52920    |
# | train/             |          |
# |    actor_loss      | -9.34    |
# |    critic_loss     | 0.00225  |
# |    ent_coef        | 3.09e-05 |
# |    ent_coef_loss   | -122     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.113    |
# |    mean_reward     | 0.00121  |
# |    min_reward      | -0.136   |
# |    n_updates       | 52818    |
# |    portfolio_value | 1.52     |
# ---------------------------------
# {'min_reward': -0.1405332168958121, 'max_reward': 0.11029115635587913, 'mean_reward': 0.001219844760115779, 'portfolio_value': 1.5370043977458807, 'weights_q0.25': 0.008974750336801049, 'weights_q0.5': 0.012414275900140192, 'weights_q0.75': 0.02241849869746523, 'weights_max': 0.03635530766444502, 'weights_std': 0.009098573694921992}
# ---------------------------------
# | time/              |          |
# |    episodes        | 43       |
# |    fps             | 117      |
# |    time_elapsed    | 454      |
# |    total_timesteps | 54180    |
# | train/             |          |
# |    actor_loss      | -8.4     |
# |    critic_loss     | 0.000961 |
# |    ent_coef        | 2.79e-05 |
# |    ent_coef_loss   | -192     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.11     |
# |    mean_reward     | 0.00121  |
# |    min_reward      | -0.141   |
# |    n_updates       | 54078    |
# |    portfolio_value | 1.53     |
# ---------------------------------
# {'min_reward': -0.13400641529870566, 'max_reward': 0.10840163373854042, 'mean_reward': 0.0012445582879787858, 'portfolio_value': 1.5681434428532703, 'weights_q0.25': 0.007928163596943299, 'weights_q0.5': 0.013949443365719539, 'weights_q0.75': 0.023152041778290024, 'weights_max': 0.033220671521092045, 'weights_std': 0.00847971386233125}
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 117      |
# |    time_elapsed    | 465      |
# |    total_timesteps | 55440    |
# | train/             |          |
# |    actor_loss      | -8.69    |
# |    critic_loss     | 0.000497 |
# |    ent_coef        | 2.53e-05 |
# |    ent_coef_loss   | -27.8    |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.108    |
# |    mean_reward     | 0.00124  |
# |    min_reward      | -0.134   |
# |    n_updates       | 55338    |
# |    portfolio_value | 1.56     |
# ---------------------------------
# {'min_reward': -0.13682501094694238, 'max_reward': 0.109616450013203, 'mean_reward': 0.0013199269871897914, 'portfolio_value': 1.6631080038591373, 'weights_q0.25': 0.008098700593257256, 'weights_q0.5': 0.013089197545831077, 'weights_q0.75': 0.021869336167023433, 'weights_max': 0.036021142252434295, 'weights_std': 0.0088348588436588}
# ---------------------------------
# | time/              |          |
# |    episodes        | 45       |
# |    fps             | 117      |
# |    time_elapsed    | 476      |
# |    total_timesteps | 56700    |
# | train/             |          |
# |    actor_loss      | -7.22    |
# |    critic_loss     | 0.000479 |
# |    ent_coef        | 1.77e-05 |
# |    ent_coef_loss   | 176      |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.11     |
# |    mean_reward     | 0.00131  |
# |    min_reward      | -0.137   |
# |    n_updates       | 56598    |
# |    portfolio_value | 1.65     |
# ---------------------------------
# {'min_reward': -0.13348951955082586, 'max_reward': 0.11577041293179813, 'mean_reward': 0.0011749272423852836, 'portfolio_value': 1.4804083254054585, 'weights_q0.25': 0.007357514734359295, 'weights_q0.5': 0.01133669814015847, 'weights_q0.75': 0.025730081831361433, 'weights_max': 0.036151295050501506, 'weights_std': 0.009852631655799216}
# ---------------------------------
# | time/              |          |
# |    episodes        | 46       |
# |    fps             | 117      |
# |    time_elapsed    | 489      |
# |    total_timesteps | 57960    |
# | train/             |          |
# |    actor_loss      | -6.74    |
# |    critic_loss     | 0.00306  |
# |    ent_coef        | 2.06e-05 |
# |    ent_coef_loss   | -136     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.116    |
# |    mean_reward     | 0.00117  |
# |    min_reward      | -0.133   |
# |    n_updates       | 57858    |
# |    portfolio_value | 1.47     |
# ---------------------------------
# {'min_reward': -0.13783528944172113, 'max_reward': 0.1116464406992507, 'mean_reward': 0.0013038882249389212, 'portfolio_value': 1.6428991634230405, 'weights_q0.25': 0.007688932054990824, 'weights_q0.5': 0.012602144972843364, 'weights_q0.75': 0.023061640593633526, 'weights_max': 0.0353042621226224, 'weights_std': 0.00958794006221207}
# ---------------------------------
# | time/              |          |
# |    episodes        | 47       |
# |    fps             | 117      |
# |    time_elapsed    | 500      |
# |    total_timesteps | 59220    |
# | train/             |          |
# |    actor_loss      | -6.58    |
# |    critic_loss     | 0.000322 |
# |    ent_coef        | 1.72e-05 |
# |    ent_coef_loss   | -125     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.112    |
# |    mean_reward     | 0.0013   |
# |    min_reward      | -0.138   |
# |    n_updates       | 59118    |
# |    portfolio_value | 1.63     |
# ---------------------------------
# {'min_reward': -0.13288634509126349, 'max_reward': 0.11885447742647448, 'mean_reward': 0.0013117315241871841, 'portfolio_value': 1.6527817204758497, 'weights_q0.25': 0.008893550571559817, 'weights_q0.5': 0.012255552872867233, 'weights_q0.75': 0.023360385123563872, 'weights_max': 0.0393230894296939, 'weights_std': 0.009029142393015256}
# ---------------------------------
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 116      |
# |    time_elapsed    | 513      |
# |    total_timesteps | 60480    |
# | train/             |          |
# |    actor_loss      | -5.58    |
# |    critic_loss     | 0.000276 |
# |    ent_coef        | 1.92e-05 |
# |    ent_coef_loss   | -113     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.119    |
# |    mean_reward     | 0.0013   |
# |    min_reward      | -0.133   |
# |    n_updates       | 60378    |
# |    portfolio_value | 1.64     |
# ---------------------------------
# {'min_reward': -0.1363875663893987, 'max_reward': 0.111258567468737, 'mean_reward': 0.0012808892826965909, 'portfolio_value': 1.6139204961977056, 'weights_q0.25': 0.008805374840711772, 'weights_q0.5': 0.011943943403131962, 'weights_q0.75': 0.021097789852108483, 'weights_max': 0.036899904597451905, 'weights_std': 0.009145096434912035}
# ---------------------------------
# | time/              |          |
# |    episodes        | 49       |
# |    fps             | 115      |
# |    time_elapsed    | 528      |
# |    total_timesteps | 61740    |
# | train/             |          |
# |    actor_loss      | -5.54    |
# |    critic_loss     | 0.000238 |
# |    ent_coef        | 1.46e-05 |
# |    ent_coef_loss   | -119     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.111    |
# |    mean_reward     | 0.00127  |
# |    min_reward      | -0.136   |
# |    n_updates       | 61638    |
# |    portfolio_value | 1.6      |
# ---------------------------------
# {'min_reward': -0.1302842007019247, 'max_reward': 0.10410780694659863, 'mean_reward': 0.0012709004005910932, 'portfolio_value': 1.6013345047447785, 'weights_q0.25': 0.008475156285735152, 'weights_q0.5': 0.0136118939273597, 'weights_q0.75': 0.02225900439915413, 'weights_max': 0.04017837607466932, 'weights_std': 0.008759710244004177}
# ---------------------------------
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 115      |
# |    time_elapsed    | 540      |
# |    total_timesteps | 63000    |
# | train/             |          |
# |    actor_loss      | -5.71    |
# |    critic_loss     | 8.94e-05 |
# |    ent_coef        | 1.54e-05 |
# |    ent_coef_loss   | -112     |
# |    learning_rate   | 0.001    |
# |    max_reward      | 0.104    |
# |    mean_reward     | 0.00126  |
# |    min_reward      | -0.13    |
# |    n_updates       | 62898    |
# |    portfolio_value | 1.59     |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[133], line 2
#       1 model_name = 'SAC-mr-it-256-256-64-dw'
# ----> 2 model.learn(total_timesteps=120_000, progress_bar=False, log_interval=1,
#       3             reset_num_timesteps=False, tb_log_name=model_name,
#       4             callback=MeanRewardCallback())
#
# File ~/Documents/CODE-W/PyCharm Projects/portfolio_optimization/venv/lib/python3.10/site-packages/stable_baselines3/sac/sac.py:302, in SAC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     293 def learn(
#     294     self: SelfSAC,
#     295     total_timesteps: int,
#    (...)
#     300     progress_bar: bool = False,
#     301 ) -> SelfSAC:
# --> 302     return super().learn(
#     303         total_timesteps=total_timesteps,
#     304         callback=callback,
#     305         log_interval=log_interval,
#     306         tb_log_name=tb_log_name,
#     307         reset_num_timesteps=reset_num_timesteps,
#     308         progress_bar=progress_bar,
#     309     )
#
# File ~/Documents/CODE-W/PyCharm Projects/portfolio_optimization/venv/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:330, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     328         # Special case when the user passes `gradient_steps=0`
#     329         if gradient_steps > 0:
# --> 330             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     332 callback.on_training_end()
#     334 return self
#
# File ~/Documents/CODE-W/PyCharm Projects/portfolio_optimization/venv/lib/python3.10/site-packages/stable_baselines3/sac/sac.py:263, in SAC.train(self, gradient_steps, batch_size)
#     261 self.critic.optimizer.zero_grad()
#     262 critic_loss.backward()
# --> 263 self.critic.optimizer.step()
#     265 # Compute actor loss
#     266 # Alternative: actor_loss = th.mean(log_prob - qf1_pi)
#     267 # Min over all critic networks
#     268 q_values_pi = th.cat(self.critic(replay_data.observations, actions_pi), dim=1)
#
# File ~/Documents/CODE-W/PyCharm Projects/portfolio_optimization/venv/lib/python3.10/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File ~/Documents/CODE-W/PyCharm Projects/portfolio_optimization/venv/lib/python3.10/site-packages/torch/optim/optimizer.py:33, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      31 try:
#      32     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33     ret = func(self, *args, **kwargs)
#      34 finally:
#      35     torch.set_grad_enabled(prev_grad)
#
# File ~/Documents/CODE-W/PyCharm Projects/portfolio_optimization/venv/lib/python3.10/site-packages/torch/optim/adam.py:116, in Adam.step(self, closure)
#     108 @_use_grad_for_differentiable
#     109 def step(self, closure=None):
#     110     """Performs a single optimization step.
#     111
#     112     Args:
#     113         closure (Callable, optional): A closure that reevaluates the model
#     114             and returns the loss.
#     115     """
# --> 116     self._cuda_graph_capture_health_check()
#     118     loss = None
#     119     if closure is not None:
#
# File ~/Documents/CODE-W/PyCharm Projects/portfolio_optimization/venv/lib/python3.10/site-packages/torch/optim/optimizer.py:230, in Optimizer._cuda_graph_capture_health_check(self)
#     228 def _cuda_graph_capture_health_check(self):
#     229     if torch.has_cuda and torch.cuda.is_available():
# --> 230         capturing = torch.cuda.is_current_stream_capturing()
#     232         if capturing and not all(group['capturable'] for group in self.param_groups):
#     233             raise RuntimeError("Attempting CUDA graph capture of step() for an instance of " +
#     234                                self.__class__.__name__ +
#     235                                " but param_groups' capturable is False.")
#
# File ~/Documents/CODE-W/PyCharm Projects/portfolio_optimization/venv/lib/python3.10/site-packages/torch/cuda/graphs.py:25, in is_current_stream_capturing()
#      19 def is_current_stream_capturing():
#      20     r"""
#      21     Returns True if CUDA graph capture is underway on the current CUDA stream, False otherwise.
#      22
#      23     If a CUDA context does not exist on the current device, returns False without initializing the context.
#      24     """
# ---> 25     return _cuda_isCurrentStreamCapturing()
#
# KeyboardInterrupt:

# %% [markdown]
# #### Saving model and running mean from env

# %%
model.save('models/' + model_name)
with open('models/' + model_name + '_obs_rms.pickle', 'wb') as handle:
    pickle.dump(train_env.obs_rms, handle)

# %% [markdown]
# ## Evaluation

# %%
mean_reward, std_reward = evaluate_policy(model, train_env, n_eval_episodes=5, deterministic=False, warn=False, return_episode_rewards=False)
print(mean_reward, std_reward)
# Out:
# {'min_reward': -0.12093659570347387, 'max_reward': 0.13205487355601875, 'mean_reward': 0.005119468725896201, 'portfolio_value': 6.4505305946292, 'weights_q0.25': 0.0046672422405370905, 'weights_q0.5': 0.004667242240612539, 'weights_q0.75': 0.035565801502095346, 'weights_max': 0.03556582807247249, 'weights_std': 0.014756218279444051}
# {'min_reward': -0.12093659570358725, 'max_reward': 0.13205487355601658, 'mean_reward': 0.005118200158448007, 'portfolio_value': 6.448932199644485, 'weights_q0.25': 0.004667275978058943, 'weights_q0.5': 0.004667275978134356, 'weights_q0.75': 0.03556555513505742, 'weights_max': 0.03556558169303568, 'weights_std': 0.01475611168274437}
# {'min_reward': -0.12093659580237294, 'max_reward': 0.13205487355601433, 'mean_reward': 0.005117685400974314, 'portfolio_value': 6.448283605227631, 'weights_q0.25': 0.004667316638730944, 'weights_q0.5': 0.004667316638806316, 'weights_q0.75': 0.035565258235646546, 'weights_max': 0.03556528477868274, 'weights_std': 0.01475598317958706}
# {'min_reward': -0.12093659590115702, 'max_reward': 0.1320548735560121, 'mean_reward': 0.005117440516629576, 'portfolio_value': 6.447975050953265, 'weights_q0.25': 0.00466736493446765, 'weights_q0.5': 0.004667364934542972, 'weights_q0.75': 0.03556490556015588, 'weights_max': 0.03556493208544551, 'weights_std': 0.01475583049296239}
# {'min_reward': -0.12093659590124684, 'max_reward': 0.13205487355600992, 'mean_reward': 0.005117684207794073, 'portfolio_value': 6.44828210182053, 'weights_q0.25': 0.004667421661558005, 'weights_q0.5': 0.00466742166163327, 'weights_q0.75': 0.03556449123046716, 'weights_max': 0.03556451773491294, 'weights_std': 0.01475565106935772}
# 6.4488007109004 0.0009195523801318582

# %%
train_env.venv.venv.envs[0].__dict__.keys()
# Out:
# dict_keys(['data', 'stock_dim', 'close_prices_pct', 'tickers', 'n_assets', 'objective', 'risk_measure', 'rewards_memory', 'actions_memory', 'portfolio_value', 'observations_range', 'current_step', 'weights', 'reward_range', 'action_space', 'observation_space'])

# %%
train_env.training = False
train_env.venv.venv.envs[0].observations_range = (0, 1761) # change to use the test period

# %%
import copy

obs = train_env.reset()
weights_states = [train_env.venv.venv.envs[0].weights]
portfolio_values = [0]
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = train_env.step(action)
    if done:
        break
    else:
        weights_states.append(copy.deepcopy(train_env.venv.venv.envs[0].weights))
        portfolio_values.append(train_env.venv.venv.envs[0].portfolio_value)
        print(train_env.render())
len(portfolio_values), len(weights_states)
# Out:
# {'min_reward': -0.006397026892399557, 'max_reward': -0.006397026892399557, 'mean_reward': -0.006397026892399557, 'portfolio_value': -0.006397026892399557, 'weights_q0.25': 0.004027668014186816, 'weights_q0.5': 0.004027668014186816, 'weights_q0.75': 0.029760664904694995, 'weights_max': 0.029760664904694995, 'weights_std': 0.012825912504156965}
# {'min_reward': -0.017693875109122646, 'max_reward': -0.006397026892399557, 'mean_reward': -0.012045451000761102, 'portfolio_value': -0.024090902001522203, 'weights_q0.25': 0.003939049938678893, 'weights_q0.5': 0.003939049938678893, 'weights_q0.75': 0.02986456196202846, 'weights_max': 0.02986456196202846, 'weights_std': 0.012921866438747234}
# {'min_reward': -0.028942241892391973, 'max_reward': -0.006397026892399557, 'mean_reward': -0.017677714631304724, 'portfolio_value': -0.05303314389391418, 'weights_q0.25': 0.00589781622290701, 'weights_q0.5': 0.00605271942452522, 'weights_q0.75': 0.02890391595058908, 'weights_max': 0.044723883378904095, 'weights_std': 0.01674158277919597}
# {'min_reward': -0.028942241892391973, 'max_reward': -0.006397026892399557, 'mean_reward': -0.016413962763114475, 'portfolio_value': -0.0656558510524579, 'weights_q0.25': 0.005134732420233382, 'weights_q0.5': 0.005135527868331868, 'weights_q0.75': 0.03794670351672591, 'weights_max': 0.03944288989179972, 'weights_std': 0.01572943357116888}
# {'min_reward': -0.028942241892391973, 'max_reward': 0.007037683751039624, 'mean_reward': -0.011723633460283656, 'portfolio_value': -0.05861816730141828, 'weights_q0.25': 0.004796595635381521, 'weights_q0.5': 0.004796599450825916, 'weights_q0.75': 0.03662442823738867, 'weights_max': 0.03667937401480594, 'weights_std': 0.014973557609159365}
# {'min_reward': -0.028942241892391973, 'max_reward': 0.007780506052896268, 'mean_reward': -0.008472943541420334, 'portfolio_value': -0.05083766124852201, 'weights_q0.25': 0.0044269847565819006, 'weights_q0.5': 0.004426984773472815, 'weights_q0.75': 0.033769112153276645, 'weights_max': 0.03377096767437245, 'weights_std': 0.014152557522473517}

# {'min_reward': -0.12093659590123335, 'max_reward': 0.13205487355600903, 'mean_reward': 0.003801543643019215, 'portfolio_value': 6.6679075498556974, 'weights_q0.25': 0.004660869629161192, 'weights_q0.5': 0.004660872924974375, 'weights_q0.75': 0.03546933907152106, 'weights_max': 0.03548917874852121, 'weights_std': 0.014767477691912285}
# {'min_reward': -0.12093659590123335, 'max_reward': 0.13205487355600903, 'mean_reward': 0.003809317903658991, 'portfolio_value': 6.685352920921524, 'weights_q0.25': 0.004658523164259939, 'weights_q0.5': 0.004658523179614348, 'weights_q0.75': 0.03549908601096359, 'weights_max': 0.03549979030232462, 'weights_std': 0.01477673803782117}
# {'min_reward': -0.12093659590123335, 'max_reward': 0.13205487355600903, 'mean_reward': 0.00378822421597968, 'portfolio_value': 6.652121723260313, 'weights_q0.25': 0.004792374481757367, 'weights_q0.5': 0.00479237448183095, 'weights_q0.75': 0.0365202378247921, 'weights_max': 0.036520263545681345, 'weights_std': 0.015121867317546214}
# {'min_reward': -0.12093659590123335, 'max_reward': 0.13205487355600903, 'mean_reward': 0.003786936661003778, 'portfolio_value': 6.653647713383632, 'weights_q0.25': 0.0049905632235753864, 'weights_q0.5': 0.004990563244999986, 'weights_q0.75': 0.038063522185332405, 'weights_max': 0.03806429344995699, 'weights_std': 0.015381228396773855}
# {'min_reward': -0.12093659590123335, 'max_reward': 0.13205487355600903, 'mean_reward': 0.0037787266762063093, 'portfolio_value': 6.643001496770686, 'weights_q0.25': 0.004400511506666377, 'weights_q0.5': 0.004400511506760656, 'weights_q0.75': 0.03360899517374584, 'weights_max': 0.03360902109517618, 'weights_std': 0.014133715712985004}
# {'min_reward': -0.12093659590123335, 'max_reward': 0.13205487355600903, 'mean_reward': 0.003768244969533376, 'portfolio_value': 6.628342901409202, 'weights_q0.25': 0.0051369885379956085, 'weights_q0.5': 0.005136988538071755, 'weights_q0.75': 0.039082527647601104, 'weights_max': 0.03908252866067612, 'weights_std': 0.015708841285288492}
# {'min_reward': -0.12093659590123335, 'max_reward': 0.13205487355600903, 'mean_reward': 0.0037834541767364227, 'portfolio_value': 6.658879351056098, 'weights_q0.25': 0.00482857057263437, 'weights_q0.5': 0.004828570572634738, 'weights_q0.75': 0.036910498223263324, 'weights_max': 0.036910498260656434, 'weights_std': 0.015089376007156574}
# {'min_reward': -0.12093659590123335, 'max_reward': 0.13205487355600903, 'mean_reward': 0.0037796682459901604, 'portfolio_value': 6.6559957811886665, 'weights_q0.25': 0.005116702967601336, 'weights_q0.5': 0.0051167029676013375, 'weights_q0.75': 0.03904021261596688, 'weights_max': 0.03904021261742672, 'weights_std': 0.015757135050685583}
# (1761, 1761)

# %%
portfolio_state = pd.DataFrame(index=train_env.venv.venv.envs[0].close_prices_pct.index, data=portfolio_values)
portfolio_state.to_csv('portfolios/' + model_name + '_portfolio.csv')

# %%
weights_df = pd.DataFrame(index=train_env.venv.venv.envs[0].close_prices_pct.columns, data=weights_states[-1])
weights_df.to_csv('portfolios/' + model_name + '_weights.csv')

# %% [markdown]
# ## Tests

# %%
with open('data/sp500_data_5y.pickle', 'rb') as f:
    data = pickle.load(f)
    close_prices = pd.DataFrame({k: v['Close'] for k, v in data.items()})

# %%
data['AAPL'].diff()

# %%
rand_w = softmax_normalization(np.random.randn(489))
rand_w

# %%
ones_w = softmax_normalization(np.ones(489))
ones_w

# %%
close_prices.diff()

# %%
(close_prices.pct_change().iloc[48] @ rand_w)

# %%
close_prices.pct_change().dropna().mean() @ rand_w

# %%
(close_prices.pct_change().dropna() @ rand_w).sum()

# %%
(close_prices.pct_change().dropna() @ ones_w).sum()
